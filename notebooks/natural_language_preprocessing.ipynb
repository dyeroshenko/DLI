# %% [markdown]
# <a href="https://colab.research.google.com/github/dyeroshenko/DLI/blob/main/notebooks/natural_language_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Natural Language Preprocessing

# %% [markdown]
# In this notebook, we clean up a dataset of natural language data (books from Project Gutenberg) and use word2vec to embed the language in word vectors.
#
# **N.B.:** Some, all or none of these preprocessing steps may be helpful to a given downstream application.

# %% [markdown]
# #### Load dependencies

# %%
import nltk
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import *
nltk.download('gutenberg')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

import string

import gensim
from gensim.models.phrases import Phraser, Phrases
from gensim.models.word2vec import Word2Vec

import spacy # for a lemmatization example

from sklearn.manifold import TSNE

import pandas as pd
from bokeh.io import output_notebook, output_file
from bokeh.plotting import show, figure
from bokeh.models import plots
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# #### Load Data

# %%
from nltk.corpus import gutenberg

# %%
# a convenient method that handles newlines, as well as tokenizing sentences and words in one shot
gberg_sents = gutenberg.sents()

# %%
gberg_sents[0:6]
# Out:
# [['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']'],
#  ['VOLUME', 'I'],
#  ['CHAPTER', 'I'],
#  ['Emma',
#   'Woodhouse',
#   ',',
#   'handsome',
#   ',',
#   'clever',
#   ',',
#   'and',
#   'rich',
#   ',',
#   'with',
#   'a',
#   'comfortable',
#   'home',
#   'and',
#   'happy',
#   'disposition',
#   ',',
#   'seemed',
#   'to',
#   'unite',
#   'some',
#   'of',
#   'the',
#   'best',
#   'blessings',
#   'of',
#   'existence',
#   ';',
#   'and',
#   'had',
#   'lived',
#   'nearly',
#   'twenty',
#   '-',
#   'one',
#   'years',
#   'in',
#   'the',
#   'world',
#   'with',
#   'very',
#   'little',
#   'to',
#   'distress',
#   'or',
#   'vex',
#   'her',
#   '.'],
#  ['She',
#   'was',
#   'the',
#   'youngest',
#   'of',
#   'the',
#   'two',
#   'daughters',
#   'of',
#   'a',
#   'most',
#   'affectionate',
#   ',',
#   'indulgent',
#   'father',
#   ';',
#   'and',
#   'had',
#   ',',
#   'in',
#   'consequence',
#   'of',
#   'her',
#   'sister',
#   "'",
#   's',
#   'marriage',
#   ',',
#   'been',
#   'mistress',
#   'of',
#   'his',
#   'house',
#   'from',
#   'a',
#   'very',
#   'early',
#   'period',
#   '.'],
#  ['Her',
#   'mother',
#   'had',
#   'died',
#   'too',
#   'long',
#   'ago',
#   'for',
#   'her',
#   'to',
#   'have',
#   'more',
#   'than',
#   'an',
#   'indistinct',
#   'remembrance',
#   'of',
#   'her',
#   'caresses',
#   ';',
#   'and',
#   'her',
#   'place',
#   'had',
#   'been',
#   'supplied',
#   'by',
#   'an',
#   'excellent',
#   'woman',
#   'as',
#   'governess',
#   ',',
#   'who',
#   'had',
#   'fallen',
#   'little',
#   'short',
#   'of',
#   'a',
#   'mother',
#   'in',
#   'affection',
#   '.']]

# %%
gberg_sents[4][14]
# Out:
# 'father'

# %% [markdown]
# #### Iteratively preprocess a sentence

# %% [markdown]
# ##### a tokenized sentence:

# %%
gberg_sents[4]
# Out:
# ['She',
#  'was',
#  'the',
#  'youngest',
#  'of',
#  'the',
#  'two',
#  'daughters',
#  'of',
#  'a',
#  'most',
#  'affectionate',
#  ',',
#  'indulgent',
#  'father',
#  ';',
#  'and',
#  'had',
#  ',',
#  'in',
#  'consequence',
#  'of',
#  'her',
#  'sister',
#  "'",
#  's',
#  'marriage',
#  ',',
#  'been',
#  'mistress',
#  'of',
#  'his',
#  'house',
#  'from',
#  'a',
#  'very',
#  'early',
#  'period',
#  '.']

# %% [markdown]
# ##### to lowercase:

# %%
[w.lower() for w in gberg_sents[4]]
# Out:
# ['she',
#  'was',
#  'the',
#  'youngest',
#  'of',
#  'the',
#  'two',
#  'daughters',
#  'of',
#  'a',
#  'most',
#  'affectionate',
#  ',',
#  'indulgent',
#  'father',
#  ';',
#  'and',
#  'had',
#  ',',
#  'in',
#  'consequence',
#  'of',
#  'her',
#  'sister',
#  "'",
#  's',
#  'marriage',
#  ',',
#  'been',
#  'mistress',
#  'of',
#  'his',
#  'house',
#  'from',
#  'a',
#  'very',
#  'early',
#  'period',
#  '.']

# %% [markdown]
# ##### remove stopwords and punctuation:

# %%
stpwrds = stopwords.words('english') + list(string.punctuation)

# %%
stpwrds
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
[w.lower() for w in gberg_sents[4] if w.lower() not in stpwrds]
# Out:
# ['youngest',
#  'two',
#  'daughters',
#  'affectionate',
#  'indulgent',
#  'father',
#  'consequence',
#  'sister',
#  'marriage',
#  'mistress',
#  'house',
#  'early',
#  'period']

# %% [markdown]
# ##### stem words:

# %%
stemmer = PorterStemmer()

# %%
[stemmer.stem(w.lower()) for w in gberg_sents[4] if w.lower() not in stpwrds]
# Out:
# ['youngest',
#  'two',
#  'daughter',
#  'affection',
#  'indulg',
#  'father',
#  'consequ',
#  'sister',
#  'marriag',
#  'mistress',
#  'hous',
#  'earli',
#  'period']

# %% [markdown]
# ##### a lemmatization example:

# %%
nlp = spacy.load('en_core_web_sm')
# Out:
# /usr/local/lib/python3.11/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %%
gutenberg.raw()[291:477]
# Out:
# "She was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister's marriage,\nbeen mistress of his house from a very early period."

# %%
spacy_doc = nlp(gutenberg.raw()[291:477])

# %%
[w.lemma_ for w in spacy_doc]
# Out:
# ['she',
#  'be',
#  'the',
#  'young',
#  'of',
#  'the',
#  'two',
#  'daughter',
#  'of',
#  'a',
#  'most',
#  'affectionate',
#  ',',
#  '\n',
#  'indulgent',
#  'father',
#  ';',
#  'and',
#  'have',
#  ',',
#  'in',
#  'consequence',
#  'of',
#  'her',
#  'sister',
#  "'s",
#  'marriage',
#  ',',
#  '\n',
#  'be',
#  'mistress',
#  'of',
#  'his',
#  'house',
#  'from',
#  'a',
#  'very',
#  'early',
#  'period',
#  '.']

# %% [markdown]
# ##### handle bigram collocations:

# %%
phrases = Phrases(gberg_sents) # train detector

# %%
bigram = Phraser(phrases) # create a more efficient Phraser object for transforming sentences

# %%
bigram.phrasegrams # output score of each bigram
# Out:
# {'two_daughters': 11.966813731181547,
#  'her_sister': 17.7960829227865,
#  "'_s": 31.066242737744524,
#  'very_early': 11.01214147275924,
#  'Her_mother': 13.529425062715127,
#  'long_ago': 63.22343628984789,
#  'more_than': 29.023584433996874,
#  'had_been': 22.306024648925288,
#  'an_excellent': 39.063874851750626,
#  'Miss_Taylor': 453.75918026073305,
#  'very_fond': 24.134280468850747,
#  'passed_away': 12.35053642325912,
#  'too_much': 31.376002029426687,
#  'did_not': 11.72841621714281,
#  'any_means': 14.096964108090186,
#  'wedding_-': 17.4695197740113,
#  'Her_father': 13.129571562488772,
#  'after_dinner': 21.528548116881705,
#  'self_-': 47.79018053120332,
#  'sixteen_years': 107.0461671612265,
#  'five_years': 40.128755673408115,
#  'years_old': 54.735425236061104,
#  'seven_years': 52.59411150244507,
#  'each_other': 79.4168405322873,
#  'a_mile': 12.783091600264584,
#  'must_be': 10.229989650632808,
#  'difference_between': 220.52537305244678,
#  'could_not': 10.870983286982371,
#  'having_been': 11.53801833156938,
#  'miles_off': 34.7868137375225,
#  'at_Hartfield': 27.2822270597084,
#  'her_husband': 27.54439519504973,
#  'in_spite': 13.441914963088442,
#  'Emma_could': 11.335111257744053,
#  'every_body': 36.972582976825784,
#  'no_means': 32.57361823161739,
#  'his_own': 10.402387689390995,
#  'obliged_to': 10.43662879984823,
#  'able_to': 11.446828804673226,
#  'very_much': 16.210274994002063,
#  'have_been': 17.981191047801964,
#  'great_deal': 118.04013764577145,
#  '"_Poor': 10.125586409383336,
#  'agree_with': 13.611743912451109,
#  '-_humoured': 33.94078127522195,
#  'for_ever': 12.4761138144463,
#  'This_is': 11.381028160111825,
#  'three_times': 35.42578086743132,
#  'my_dear': 24.47894249615343,
#  'How_often': 12.377968718725874,
#  'My_dear': 84.80698289930199,
#  'so_far': 10.161632478973766,
#  '"_No': 15.063706270011586,
#  'We_must': 18.765646900386386,
#  'last_night': 23.592598950882213,
#  'doubt_whether': 22.924130736398396,
#  'anywhere_else': 16.100101533414907,
#  'I_am': 16.951297329049222,
#  'very_glad': 18.28434074650975,
#  'am_sure': 65.14460207447972,
#  'very_pretty': 20.068178868120455,
#  'be_able': 11.347612277348256,
#  'immediately_afterwards': 41.06053966483414,
#  'sensible_man': 14.541388094211703,
#  'intimate_friend': 21.89876062322946,
#  'connected_with': 18.375854281808998,
#  'than_usual': 28.951968704471486,
#  'Brunswick_Square': 10881.307917888564,
#  'some_time': 12.926553753557874,
#  'poor_Isabella': 41.30241100647833,
#  'It_is': 11.705870174225897,
#  'am_afraid': 25.627391867391864,
#  'moonlight_night': 14.745374344301382,
#  'Look_at': 13.630464729284448,
#  '"_Well': 21.191330893669,
#  'vast_deal': 61.90400400400401,
#  'an_hour': 41.75757187695002,
#  'pretty_well': 17.716415202444615,
#  'tolerably_well': 18.357580705009276,
#  '"_Ah': 17.279509006244886,
#  'Ah_!': 37.53295698121932,
#  "'_Tis": 23.23934394278894,
#  'Miss_Woodhouse': 294.5270970174429,
#  'you_please': 13.035980721875688,
#  'any_rate': 83.92034351736973,
#  ',"_said': 36.03254133384804,
#  'My_dearest': 26.665272507761294,
#  'so_much': 20.56443776042493,
#  'much_less': 19.10443556993451,
#  'any_body': 21.716438732250484,
#  'has_been': 29.2606767165493,
#  'been_used': 14.09410182779525,
#  'Well_,"': 12.493546273257476,
#  'tell_you': 11.612165547868624,
#  'Every_body': 72.20010799293668,
#  '"_Dear': 20.048661090579007,
#  'every_thing': 27.27716850667998,
#  'very_sorry': 20.255731941654293,
#  'turned_away': 19.3446247292484,
#  'divided_between': 35.82806127178346,
#  'knows_how': 14.800957338598694,
#  'how_much': 15.417663894373641,
#  'four_years': 16.257604884476734,
#  'years_ago': 163.33147420261938,
#  'any_thing': 35.72804044966351,
#  'need_not': 13.478832663938945,
#  'his_wife': 10.870850757012368,
#  'Ever_since': 99.63818474758324,
#  'leave_off': 10.507247077643713,
#  'you_mean': 10.573995913362893,
#  'young_lady': 113.30511794581633,
#  'depend_upon': 66.33685452578166,
#  'quarrel_with': 10.691406127597961,
#  '-_hearted': 49.037248488452775,
#  'their_own': 10.164510720981893,
#  'You_are': 12.60019671587268,
#  'more_likely': 11.17688298714827,
#  'have_done': 12.664105519891397,
#  ',"_rejoined': 11.956633540853021,
#  'any_longer': 16.396201569570135,
#  'very_well': 13.844437162007255,
#  'young_man': 25.863812524396362,
#  'dine_with': 13.88397879070013,
#  'much_better': 10.763384154831522,
#  'I_dare': 13.676468274997303,
#  'dare_say': 128.21086697682205,
#  'Depend_upon': 92.29475412282666,
#  'take_care': 72.93974751004718,
#  'CHAPTER_II': 335.5512750949539,
#  'entering_into': 16.437457915441048,
#  'never_seen': 14.015206798866856,
#  'refrain_from': 12.438010669696954,
#  'at_once': 21.418172245725966,
#  'three_years': 37.3552600780725,
#  'any_other': 10.20840196855241,
#  'twenty_years': 85.29044131115464,
#  'an_easy': 10.427467282325322,
#  'according_to': 12.093327441482012,
#  'had_begun': 12.032976708302646,
#  'passed_through': 31.462199837199837,
#  'its_being': 16.06447342496047,
#  'deal_better': 19.992919953446272,
#  'fine_young': 10.403137320870965,
#  'belonging_to': 10.512393800210106,
#  'Frank_Churchill': 1750.6779772753714,
#  'Miss_Bates': 400.42607736396553,
#  'a_few': 11.554600796586188,
#  'few_days': 35.91529644067919,
#  'I_suppose': 12.338158409520453,
#  'very_handsome': 19.759437654764756,
#  'an_irresistible': 11.369078040261053,
#  'good_sense': 17.373370904818092,
#  'had_already': 11.990720435581183,
#  'She_felt': 13.338332744482605,
#  'most_fortunate': 11.471572464709046,
#  'long_enough': 15.18952997655465,
#  'know_how': 12.782869530582152,
#  'dear_Emma': 28.38977406756079,
#  'at_Randalls': 27.033755046414154,
#  'few_weeks': 134.46858012611438,
#  'no_longer': 44.45340841020726,
#  'CHAPTER_III': 354.1930126002291,
#  'Donwell_Abbey': 753.4827901309778,
#  'card_-': 15.66232807325151,
#  'drawing_-': 20.084717344971075,
#  '-_room': 10.86339885106585,
#  'thrown_away': 14.820643707910946,
#  'After_these': 11.091988134657838,
#  'an_invitation': 10.459551797040168,
#  'old_lady': 10.886003613395486,
#  'those_who': 15.975643084740117,
#  'as_possible': 11.70949877112537,
#  'young_ladies': 113.63480411788264,
#  '-_fashioned': 34.9390395480226,
#  "Goddard_'": 15.29483969345862,
#  'found_herself': 11.22605649143189,
#  's_sake': 28.09200095758,
#  'much_pleased': 13.276184200965725,
#  'be_allowed': 10.13327478977725,
#  'Miss_Smith': 165.2431687101718,
#  'Harriet_Smith': 180.54871092346391,
#  'several_years': 17.577367349955093,
#  'pretty_girl': 40.4556337659619,
#  'blue_eyes': 35.59533676681832,
#  'They_were': 10.65337155345379,
#  'due_time': 21.04160963161683,
#  'its_own': 10.834370434674414,
#  'better_than': 42.51368036077655,
#  'body_else': 39.46983722534385,
#  'apple_-': 28.219993481095173,
#  'You_need': 14.652632145780382,
#  'half_-': 14.007817698976803,
#  'much_more': 10.555945043417811,
#  'little_girl': 35.05677573772557,
#  'at_last': 22.75660921756972,
#  'CHAPTER_IV': 335.5512750949539,
#  'every_respect': 12.224980231945176,
#  'guided_by': 23.954538020555372,
#  'different_sort': 14.490845895493242,
#  '-_Mill': 12.705105290190035,
#  'good_deal': 39.176849314155014,
#  'very_happy': 11.360756752157577,
#  'drink_tea': 32.50399453379586,
#  'large_enough': 10.829067985816225,
#  'had_taken': 10.962547054002629,
#  'doing_something': 10.716846747710358,
#  'three_miles': 16.651749532156657,
#  'thing_else': 12.21019907747794,
#  'very_obliging': 25.34927857025742,
#  'on_purpose': 10.833361556419508,
#  'very_clever': 21.69532850607617,
#  '"_You': 11.717061811021024,
#  'know_what': 10.687860772182088,
#  'Miss_Nash': 337.68125042659204,
#  'does_not': 13.23025142257054,
#  '"_Oh': 20.296685763864517,
#  'Oh_yes': 23.468003288849534,
#  'very_entertaining': 16.054543094496367,
#  'soon_as': 12.01164260504438,
#  'Oh_!': 31.12698837846826,
#  'have_seen': 13.438796505596505,
#  'on_horseback': 54.889031885858834,
#  'their_families': 35.26311487873489,
#  'no_doubt': 40.18959620751882,
#  'very_respectable': 10.884435996268722,
#  'respectable_young': 27.70496528037034,
#  'very_odd': 18.206182890665982,
#  'perfectly_right': 16.998927982407917,
#  'years_hence': 17.990952464071682,
#  'young_woman': 30.4001550358284,
#  'very_desirable': 14.595039176814879,
#  'Dear_Miss': 32.278354820188945,
#  'thirty_years': 72.53269372866845,
#  'can_afford': 26.391592873146273,
#  'good_luck': 51.57752734020705,
#  'acquainted_with': 27.730834643457214,
#  'your_own': 10.134692346685467,
#  '"_Yes': 27.046036922192854,
#  'next_day': 33.66839067944251,
#  'an_opportunity': 39.49570340028189,
#  'few_yards': 127.20000822740548,
#  'Robert_Martin': 1963.7208109428432,
#  'few_minutes': 316.36383789006993,
#  'Only_think': 11.416616668358916,
#  'been_able': 15.917680792356478,
#  '-_morrow': 31.19125329892675,
#  'should_happen': 20.434212265397832,
#  'Do_you': 17.542972188763283,
#  'compared_with': 15.313211901507499,
#  '"_Certainly': 25.246462114062453,
#  'You_must': 12.864839977038008,
#  'an_old': 10.467761806300013,
#  'old_man': 11.807109991026596,
#  'more_valuable': 17.665941085058734,
#  ',"_replied': 68.6325679964557,
#  'very_bad': 15.601593602802112,
#  'deal_too': 12.720000822740548,
#  'no_more': 17.350760547573774,
#  'very_agreeable': 21.406057459328487,
#  'fixed_on': 10.722857321964225,
#  'same_time': 18.367425129939775,
#  'pleasing_young': 23.351327879169286,
#  'CHAPTER_V': 236.1286750668194,
#  'very_differently': 48.1636292834891,
#  '"_Perhaps': 10.879118421244423,
#  'ever_since': 42.928016104400946,
#  'twelve_years': 39.389282288763006,
#  'very_neatly': 22.935061563566236,
#  'ten_years': 36.45848645037043,
#  'being_able': 14.368918278390662,
#  'her_mother': 11.543621348228921,
#  'have_spoken': 11.59021954484605,
#  'Yes_,"': 26.304593789876648,
#  '"_Thank': 24.575778111032328,
#  'Thank_you': 27.91888466552739,
#  '"_Why': 10.548941903388105,
#  'could_possibly': 30.820114126236575,
#  'How_can': 16.088661540487763,
#  'much_mistaken': 10.098977725520935,
#  'Very_well': 84.54149008885851,
#  'oh_!': 22.810780631748376,
#  'look_at': 10.281997140291956,
#  'any_harm': 10.323534321581198,
#  '"_Very': 19.596435652445642,
#  'an_angel': 25.81927176790378,
#  'an_end': 18.27126745760167,
#  'many_years': 19.719030792857517,
#  ',"_cried': 34.723966485732284,
#  'much_obliged': 42.98889166944722,
#  'John_Knightley': 175.90370362419566,
#  'ill_-': 22.276568839343266,
#  'cared_for': 11.003932384341637,
#  'I_assure': 13.117491742454515,
#  'assure_you': 32.47600092425324,
#  'soon_afterwards': 80.80970084767553,
#  'CHAPTER_VI': 151.7970054000982,
#  'most_agreeable': 28.296545412948984,
#  'no_scruple': 27.38072257150447,
#  'infinitely_superior': 278.568018018018,
#  'am_glad': 17.031537511870845,
#  'Exactly_so': 26.019606605658986,
#  'Did_you': 15.109886745810456,
#  'very_interesting': 17.838381216107074,
#  'No_sooner': 65.68697776518907,
#  "Don_'": 25.40572346287943,
#  "'_t": 30.669962908216693,
#  't_pretend': 22.215392905253704,
#  'why_should': 22.803134218289085,
#  'cannot_imagine': 50.34105640180307,
#  'back_again': 19.215480532814567,
#  'almost_every': 10.072259575009545,
#  'higher_than': 46.27167976056865,
#  'ten_times': 32.71643894251348,
#  'dear_Isabella': 10.167718917496957,
#  'must_allow': 16.27068909786588,
#  'sitting_down': 17.45874757620558,
#  'fore_-': 15.528462021343378,
#  'must_confess': 12.590414182872406,
#  'depended_on': 20.58338695719706,
#  'no_sooner': 28.749758700079695,
#  'after_breakfast': 12.17388137561763,
#  'sooner_than': 16.3893318492269,
#  'at_home': 15.749528854479703,
#  'at_least': 41.37059021349224,
#  'Upon_my': 19.147177205335975,
#  'Will_you': 14.912145378521789,
#  "'_d": 30.546910997373118,
#  'She_paused': 28.95364951542675,
#  'replied_Emma': 16.33104387030484,
#  'can_hardly': 26.420626528672287,
#  'am_persuaded': 14.509626277861573,
#  'Are_you': 16.465332468596394,
#  'I_beg': 10.231643559114522,
#  'beg_your': 44.837927443381055,
#  'your_pardon': 42.182804133556154,
#  'dear_Miss': 19.29791549647382,
#  'little_while': 10.254870302373984,
#  '`_No': 11.44545824696476,
#  'entered_into': 58.47423553525749,
#  'older_than': 59.834068655907735,
#  'advise_you': 10.800158446902824,
#  'run_away': 41.70122298206315,
#  'At_last': 78.82820279093207,
#  '"_Indeed': 16.73627360604856,
#  'Dear_me': 11.639624322425217,
#  'have_borne': 11.406974967061924,
#  'good_opinion': 14.834508731529455,
#  'good_natured': 34.331291635825316,
#  'thank_you': 16.887520480611688,
#  'merely_because': 11.301099005522438,
#  'Emma_felt': 16.55226511478519,
#  'no_difficulty': 13.258034087254797,
#  'protest_against': 10.157197996222386,
#  'Let_us': 32.264040693882876,
#  'cried_Emma': 14.204759677426091,
#  '"_Has': 11.456377766045145,
#  'next_morning': 76.77797550074492,
#  'dear_sir': 30.138577189712098,
#  'am_going': 10.080878050929597,
#  'sat_down': 58.92285841199917,
#  'depends_upon': 18.878472434214544,
#  'has_happened': 16.886495752427184,
#  'presently_added': 24.986707070707073,
#  'could_afford': 16.180559916274202,
#  'Certainly_,"': 17.04927375269783,
#  'stood_up': 10.28632971468491,
#  '"_Nonsense': 10.024330545289503,
#  'are_mistaken': 10.34529425541169,
#  'does_seem': 14.17908976269632,
#  'few_moments': 388.789590364635,
#  'nobody_knows': 38.60305867665418,
#  'very_likely': 25.18359701097469,
#  'all_probability': 13.453639483026294,
#  'no_harm': 27.98918307309346,
#  'cannot_help': 20.51549678061432,
#  'very_different': 17.75617669437386,
#  'common_sense': 145.78524280999528,
#  '.--_She': 30.440671188909267,
#  '-_natured': 48.041179378531076,
#  'an_hundred': 30.38185737390911,
#  'exactly_what': 14.387504885629733,
#  'every_man': 12.828795338958601,
#  'be_satisfied': 12.272908603731747,
#  'less_than': 36.58643688514103,
#  'large_fortune': 38.26270688321733,
#  'no_use': 14.694321113374066,
#  'these_words': 26.137410685805424,
#  'well_acquainted': 11.682096812278632,
#  'twenty_thousand': 77.04104378157882,
#  'thousand_pounds': 448.56455512572535,
#  'Good_morning': 19.263291344272915,
#  'walked_off': 10.916907922609802,
#  'cast_down': 15.322709019072686,
#  'its_effects': 29.72249056785139,
#  'deal_more': 10.737496923771433,
#  'longer_than': 18.302185706512955,
#  'perfectly_satisfied': 93.75697392359005,
#  'three_hundred': 49.30309130408786,
#  'looking_at': 12.747008682016011,
#  'next_moment': 24.667278275263754,
#  'ready_wit': 70.12901152901154,
#  'very_pleasant': 11.645782555593218,
#  'an_idea': 14.230682717061454,
#  'Give_me': 25.719421458776054,
#  'arrive_at': 11.92665663812389,
#  'very_superior': 10.703028729664243,
#  'pre_-': 49.32570289132602,
#  'have_chosen': 12.418092369477911,
#  'without_exception': 55.117736185383244,
#  'her_cheeks': 10.316064715093864,
#  'sit_down': 36.04958112355487,
#  'reason_why': 38.722303389547506,
#  'could_hardly': 23.719027600038913,
#  'It_seemed': 10.045411819743176,
#  'an_offering': 11.109001091627631,
#  'let_us': 32.253455378694596,
#  'Have_you': 15.500622663363384,
#  '"_Aye': 19.50680538542822,
#  'Very_true': 128.88521410135147,
#  'can_easily': 15.161836814749437,
#  'Nobody_could': 15.935399917542775,
#  'dear_mother': 13.460467748430139,
#  'those_things': 16.269842914134045,
#  'next_week': 51.500749500333114,
#  'Why_should': 13.316921218220724,
#  '.--_Poor': 33.94933025911287,
#  'taken_away': 33.882342535970594,
#  'stay_longer': 32.079105716360615,
#  'three_days': 38.359912674236874,
#  'cannot_bear': 21.2053080048691,
#  'We_are': 13.053427143739613,
#  'four_o': 13.636425778378856,
#  "o_'": 29.05179422396496,
#  "'_clock": 18.373899375590025,
#  'ask_whether': 11.352902840883013,
#  're_-': 17.206160179428213,
#  'Of_course': 64.52969306765831,
#  'ran_away': 15.685508857974714,
#  'who_lived': 14.515376080230448,
#  'A_few': 27.798793006840953,
#  '.--_Emma': 10.090713174013455,
#  'thus_began': 10.569835629596586,
#  'Never_mind': 58.818813011223135,
#  'good_fortune': 19.83585738958796,
#  'Those_who': 18.714038582776446,
#  'Jane_Fairfax': 897.6983416183941,
#  'nothing_else': 34.14808689686209,
#  'present_instance': 15.747924624395212,
#  'These_are': 23.59005438958226,
#  'once_more': 21.461454181291767,
#  'still_greater': 12.724188305008024,
#  'here_comes': 13.200741413619147,
#  'turned_back': 28.862454905522338,
#  'will_bring': 12.921944022284055,
#  'each_side': 22.901592275974444,
#  'waiting_for': 11.22850243300167,
#  'still_remained': 13.210905890445488,
#  'she_hoped': 14.771734566364694,
#  'ten_minutes': 192.59628296373643,
#  'most_favourable': 12.48377003512455,
#  'ten_days': 17.36302410708332,
#  'many_months': 10.650678561587215,
#  'little_ones': 64.8622484431334,
#  '-_tempered': 31.944264729620663,
#  'passed_over': 23.11431354773038,
#  'sir_,"': 26.985788449773853,
#  'cannot_deny': 34.78623560349313,
#  'talking_about': 19.191191650605955,
#  'never_forget': 21.690200998246322,
#  'cannot_tell': 18.28907708359457,
#  'two_years': 12.9458705561574,
#  'indeed_!--': 15.372462749108678,
#  'most_amiable': 17.20735869706357,
#  ',"_observed': 11.710949290013575,
#  'our_lives': 19.654875413170608,
#  'think_differently': 12.463139862958485,
#  'shake_hands': 44.83992241738721,
#  'How_long': 18.446626247771526,
#  'South_End': 1381.4318689501117,
#  'perfectly_convinced': 75.68177368034593,
#  'tells_me': 12.932915913805795,
#  'bad_cold': 14.307186896320372,
#  'far_off': 27.665131723254174,
#  'am_sorry': 26.67524083393242,
#  'Ah_!"': 17.41235304055111,
#  'an_interval': 11.127182762808692,
#  'perfectly_well': 14.848043217286914,
#  'He_paused': 28.88198206613114,
#  'can_tell': 12.430822730105128,
#  'morrow_morning': 22.316089764922395,
#  'own_feelings': 10.723815634320593,
#  'sore_throat': 129.16060985797827,
#  '&_c': 4365.324705882353,
#  'well_satisfied': 19.87160797964922,
#  'looked_at': 13.030752013575848,
#  'well_pleased': 19.251395495889877,
#  'set_forward': 30.104250841148257,
#  'eldest_daughter': 86.17906911928651,
#  'short_time': 10.749383663832438,
#  'Ha_!': 53.03251532865493,
#  '"_Quite': 17.433618339633917,
#  ',"_continued': 41.17971551769827,
#  'dining_-': 27.583452274754684,
#  'such_circumstances': 10.212955347912395,
#  'enter_into': 69.91980623618285,
#  'gone_through': 11.358845786496214,
#  'turn_away': 25.69282323847976,
#  ',"_repeated': 16.023102816168517,
#  'several_times': 100.66202138582125,
#  'great_curiosity': 12.762131764948666,
#  'upper_end': 50.599001800032724,
#  'an_odd': 26.95760772433033,
#  'In_short': 17.859158861411398,
#  'dearest_Emma': 41.198769763723575,
#  'continued_Mrs': 12.808985040466856,
#  'go_home': 10.887636156851284,
#  'covered_with': 10.080468634592364,
#  'hardly_knew': 30.25731454547072,
#  'knew_how': 10.771586203292852,
#  'set_off': 12.87623069823977,
#  'can_get': 10.915759166817718,
#  'got_home': 13.02303200594452,
#  'most_extraordinary': 46.22702963501566,
#  'an_inch': 63.919483204134366,
#  'at_ease': 17.60601694199241,
#  'tete_-': 10.750473707083877,
#  'well_known': 14.650186556114896,
#  'Smith_!--': 18.891159579667644,
#  'extremely_sorry': 73.46994297481388,
#  'Every_thing': 22.46842755413457,
#  'many_weeks': 20.757955155746508,
#  'Am_I': 15.552098209854075,
#  'madam_,"': 15.249039878189363,
#  'extremely_well': 29.947748184019368,
#  '!--_Such': 19.885431136492258,
#  'poor_Harriet': 12.145847347359634,
#  '-_headed': 37.268308851224106,
#  'an_instant': 43.261013866434524,
#  'thirty_thousand': 42.25608127995963,
#  'so_easily': 10.348707172705279,
#  'worth_having': 21.664774916798038,
#  'poor_girl': 16.40337746734157,
#  'laugh_at': 11.791126449054302,
#  'knowing_what': 15.75053166426834,
#  'many_days': 14.230254790394108,
#  'whole_party': 21.733756466486728,
#  'six_weeks': 18.238203373835084,
#  'too_late': 87.81454226528567,
#  '-_minded': 20.81474696477942,
#  'her_companions': 11.854581263120794,
#  'drew_near': 135.39134997206745,
#  'three_months': 82.38692831354996,
#  'other_side': 28.113809270630334,
#  'an_unnatural': 19.227117273970897,
#  'get_rid': 302.70239843367597,
#  'watering_-': 20.552376204719177,
#  'while_ago': 15.477085481465169,
#  'at_Weymouth': 43.7310743397876,
#  'present_occasion': 32.735843313703434,
#  'No_,"': 11.56716665027149,
#  'their_hearts': 18.284578085269942,
#  'break_through': 11.454968114101241,
#  'burst_forth': 49.665004880339026,
#  'young_men': 28.05813977151226,
#  '-_bred': 27.95123163841808,
#  'nobody_else': 96.32925917464537,
#  'something_else': 38.92533060859677,
#  'walking_together': 11.84464959491295,
#  'burst_out': 11.102169937858887,
#  '-_sized': 27.17480853735091,
#  'how_long': 10.246816619029866,
#  'Miss_Fairfax': 273.22756777255375,
#  'extremely_happy': 19.519016507275197,
#  "don_'": 30.892577640288216,
#  "ma_'": 29.826517196587346,
#  's_handwriting': 11.482861705288176,
#  "Ma_'": 17.287270917893842,
#  'without_seeming': 24.251803921568627,
#  'Colonel_Campbell': 896.7708845596117,
#  'those_days': 24.94261977039944,
#  'Miss_Campbell': 75.31616124710754,
#  'most_charming': 10.48020200479592,
#  'caught_hold': 25.411776791584487,
#  'four_months': 21.51366300812301,
#  'may_guess': 13.36692964443964,
#  'Bless_me': 16.96059544124817,
#  'running_away': 11.650452540443363,
#  'My_father': 11.188894979347538,
#  'five_minutes': 145.59218386745533,
#  'nine_years': 22.042968784808547,
#  'hundred_pounds': 62.909463904241974,
#  'more_honourable': 10.64796448962444,
#  'rather_than': 19.03811275415246,
#  'few_months': 59.13801429630161,
#  'she_wished': 11.819087018586881,
#  'without_feeling': 13.668488522623221,
#  'twelve_thousand': 59.1856010235332,
#  'passed_between': 19.790738607270864,
#  ",'_said": 30.379793675936877,
#  'Miss_Hawkins': 356.6758207630878,
#  'dear_Jane': 28.087065128531204,
#  'three_minutes': 10.882367432840969,
#  'have_suffered': 12.705105290190035,
#  'hour_ago': 35.65865950134926,
#  'looked_round': 11.609345695809429,
#  'help_thinking': 32.395023572551075,
#  'a_series': 10.464298240216587,
#  'laughed_at': 12.563958901229748,
#  'weeks_ago': 66.07767923923497,
#  'She_wished': 10.481853991240559,
#  'twenty_miles': 32.079105716360615,
#  'elder_sister': 20.892601351351352,
#  'alas_!': 57.08794297143443,
#  'no_fault': 10.495943652410048,
#  'driven_away': 15.108423197384944,
#  'setting_off': 17.077163107511044,
#  'little_farther': 13.377838741396264,
#  'spot_where': 40.488884971796935,
#  'front_door': 45.13461833203179,
#  'they_parted': 10.443101887710071,
#  'without_delay': 17.832208765859285,
#  'six_months': 149.72514602185032,
#  'months_ago': 33.90373070913626,
#  'leaned_back': 12.550400811770675,
#  'at_Oxford': 14.908320797654863,
#  'turned_round': 11.258866238141938,
#  'pass_through': 22.187894661308842,
#  'clock_struck': 287.94205291005295,
#  'four_hours': 47.339972748289114,
#  'faster_than': 39.88937910393849,
#  'musical_society': 113.40931597285898,
#  'worth_while': 39.414977692797954,
#  'mixed_with': 10.669850873308452,
#  'extremely_glad': 72.78966572504707,
#  'knew_nothing': 12.448864562804845,
#  'make_amends': 67.17951224811254,
#  'amends_for': 15.103436605959109,
#  'oftener_than': 50.68297580265126,
#  'old_woman': 19.444449684793035,
#  'post_-': 12.22866384180791,
#  'just_going': 13.26013774293703,
#  'At_least': 28.035284695357834,
#  'their_lives': 14.905906047774408,
#  'six_days': 14.20782138820221,
#  'may_prove': 10.693543715551712,
#  'stronger_than': 58.08610709966773,
#  'particular_friend': 19.81788291694974,
#  'Hum_!': 26.95819529206626,
#  'good_tidings': 31.69042304845414,
#  'among_themselves': 14.912692334403358,
#  'next_summer': 20.51374391862008,
#  'breaking_up': 10.278262005104766,
#  'perfectly_safe': 16.44561748750133,
#  'two_ladies': 10.206988182478378,
#  'same_moment': 15.560860129375872,
#  'well_worth': 11.682096812278632,
#  ',"_added': 22.00020571516956,
#  'little_girls': 24.596639156806205,
#  'be_ashamed': 15.57521865836133,
#  'been_staying': 13.958581617912605,
#  'shut_up': 33.02080970890481,
#  'too_large': 13.758850077869242,
#  'At_first': 13.62235091488103,
#  'worse_than': 50.56400168104879,
#  'opposite_side': 21.484700834657843,
#  'short_pause': 86.61965123608095,
#  'large_party': 14.15971883013799,
#  'six_years': 24.75055888120844,
#  'who_knows': 17.154535367545076,
#  'extremely_fond': 34.25396034119863,
#  'or_twice': 10.479935604134893,
#  'somebody_else': 146.97092685503037,
#  'five_couple': 31.782351731935453,
#  '"_Don': 12.43524548656166,
#  'bad_news': 32.31039707419018,
#  'baked_apples': 613.5128968253968,
#  'will_send': 16.247890610812963,
#  'William_Larkins': 5074.223589743589,
#  'low_voice': 55.283668345011634,
#  'one_leg': 10.745803649000868,
#  'an_immediate': 14.761464229693788,
#  'Tell_me': 25.092668376242766,
#  ',"_resumed': 28.97963722613529,
#  'many_times': 11.523152448113748,
#  'Nothing_can': 15.5144376709064,
#  'few_words': 11.709704106675987,
#  'no_objection': 30.84522216218463,
#  'It_seems': 18.227904675031336,
#  'astonished_at': 13.982976748145251,
#  'four_times': 17.904617144015226,
#  'other_end': 10.241020603889318,
#  'few_hours': 78.07853039580834,
#  'an_extraordinary': 10.355991878257594,
#  'look_forward': 11.731590179742954,
#  'Alas_!': 24.207359037773784,
#  'immediately_followed': 12.604630780832807,
#  'wait_till': 29.399153804709538,
#  '-_bye': 39.93033091202583,
#  'contrast_between': 166.24220430107528,
#  'dared_not': 11.783382014386875,
#  'three_weeks': 21.40939225562999,
#  '-_sighted': 32.25142112125163,
#  'Maple_Grove': 16731.47346514048,
#  'My_brother': 11.063251359603091,
#  'at_Maple': 11.541925778829572,
#  'almost_fancy': 16.725382014874917,
#  'left_behind': 29.19139358595579,
#  'barouche_-': 13.97561581920904,
#  '-_landau': 19.965165456012915,
#  'whose_name': 31.460744776298874,
#  'most_serious': 10.186756348661634,
#  'We_cannot': 11.86846921192564,
#  'waited_for': 10.711792586527258,
#  'E_.,': 566.3195970695971,
#  'person_who': 10.409305441471528,
#  'greater_part': 16.18360863375623,
#  'drew_back': 15.195552552368083,
#  'Her_manners': 10.694144704987204,
#  'third_time': 13.58362630188472,
#  'very_extraordinary': 11.12691105559154,
#  'better_acquainted': 13.449782514136581,
#  'According_to': 10.652559050879573,
#  'have_committed': 16.773483913206135,
#  'hardly_less': 12.999957957579197,
#  'will_shew': 12.349694416837725,
#  'little_boys': 17.749466634776372,
#  'easily_believe': 21.82456945228684,
#  'my_lord': 36.09212316660775,
#  '"_Excuse': 17.18456664906772,
#  'Excuse_me': 37.6902120916626,
#  'put_forth': 10.696077873443938,
#  'drawing_near': 18.702625052924454,
#  'great_joy': 10.008039650578848,
#  'eight_o': 65.15181205225453,
#  'spread_abroad': 194.30906996229578,
#  'few_lines': 43.57778059642595,
#  'good_news': 24.794821736984947,
#  'most_likely': 19.419197832415968,
#  'talk_about': 21.82456945228684,
#  'tells_us': 30.445234478296342,
#  'dear_madam': 68.52158400921863,
#  'eleven_years': 16.99145510495659,
#  'your_sister': 15.96501961999174,
#  'two_hours': 15.078657986492088,
#  'two_months': 19.986458535324154,
#  'door_opened': 32.95997776754137,
#  'Who_can': 10.979605329969967,
#  'began_talking': 13.574813692886854,
#  'mean_?"': 26.417439208554274,
#  'In_spite': 11.906105907607598,
#  'many_hours': 13.12438455008489,
#  'few_steps': 22.23496206809765,
#  'most_excellent': 12.940493329092522,
#  'later_than': 11.966813731181547,
#  'whole_story': 36.394832862523536,
#  'whole_history': 19.243869803335823,
#  'lined_with': 13.540103155017157,
#  '-_plaister': 17.4695197740113,
#  'Lord_bless': 16.701184413580247,
#  'these_things': 42.22024236217784,
#  'laid_down': 12.408517237129121,
#  'forty_years': 161.26435572340617,
#  'faint_smile': 24.270839874411305,
#  'turned_towards': 11.117214558790044,
#  'totally_different': 158.3259088581669,
#  'Box_Hill': 8589.180555555555,
#  'some_surprise': 22.39728373344371,
#  'may_depend': 21.164305270362764,
#  ',"_interrupted': 30.235165275720284,
#  'whatever_else': 18.739462440532105,
#  'mid_-': 25.824507492016703,
#  'larger_than': 19.006115925994223,
#  'were_assembled': 18.151482242442032,
#  'insisted_on': 11.611141360470139,
#  'clothed_with': 12.658921838579532,
#  'twenty_minutes': 11.181099087860133,
#  'quite_alone': 11.34125512474631,
#  'etc_.,': 3964.237179487179,
#  'As_soon': 20.834318136064653,
#  'without_knowing': 34.569457344341245,
#  ',"_whispered': 26.71560306784347,
#  "shan_'": 22.473452193261995,
#  'looking_round': 17.251680754316958,
#  'Pardon_me': 10.147364793909164,
#  ',"_answered': 22.574837953998617,
#  'An_old': 19.494650501535183,
#  'Shall_we': 13.344431737263449,
#  'old_age': 48.2305151350481,
#  'an_infant': 23.77170862963675,
#  'be_forgiven': 18.33315259385065,
#  'lie_down': 31.29163861453632,
#  'four_miles': 16.30599061329958,
#  'great_hurry': 19.653682918020948,
#  'without_waiting': 19.24746342981637,
#  'comes_back': 15.420287686817213,
#  'heightened_by': 11.874899189677024,
#  'In_fact': 39.68262953497974,
#  'cut_off': 155.49937138546645,
#  'never_mind': 11.197235791371655,
#  'trembling_voice': 11.950048791799114,
#  'More_than': 24.232797805642633,
#  'time_past': 13.32652296494053,
#  'second_time': 20.94530935870325,
#  'five_hundred': 85.88703405366368,
#  'turning_away': 10.732190271245857,
#  'an_arrow': 14.857317893522966,
#  '--_oh': 12.810820328683883,
#  'presented_themselves': 11.894541467918142,
#  'at_random': 18.66781039010696,
#  'far_distant': 26.635412180205016,
#  'few_seconds': 96.54154470592827,
#  'passing_through': 15.455115709501674,
#  'will_heal': 10.57744672117128,
#  'rose_early': 50.250699385933345,
#  'east_wind': 148.38612561750176,
#  'gone_mad': 20.604417938295462,
#  'freed_from': 25.542343339556247,
#  'sinned_against': 81.41629018847007,
#  'locked_up': 13.137628126825643,
#  'deep_sigh': 47.7618937287612,
#  'ten_thousand': 127.07678714010615,
#  'happier_than': 23.413331213181287,
#  'contend_with': 10.669850873308452,
#  'had_formerly': 11.685871610947764,
#  'little_boy': 26.45163569321534,
#  'fancying_herself': 29.039303155522166,
#  'right_hand': 45.67275064863757,
#  'surrounded_by': 30.406938834172983,
#  'infinitely_more': 12.604887693122986,
#  'such_cases': 14.9147687533664,
#  'No_wonder': 19.25353071890846,
#  'poor_fellow': 72.63216713721062,
#  'Poor_fellow': 45.430376492194675,
#  'days_ago': 15.442637278485753,
#  'help_laughing': 20.696820615796522,
#  'draw_near': 83.03353576666461,
#  'at_intervals': 31.38593852137866,
#  'into_temptation': 11.801251836726905,
#  'stood_before': 10.3924315864046,
#  'Sir_Walter': 1001.312012557628,
#  'Walter_Elliot': 158.52514448173005,
#  'Kellynch_Hall': 4945.285774410774,
#  'arising_from': 10.216937335822498,
#  'Charles_Musgrove': 248.91721824686942,
#  'first_year': 36.52536994480359,
#  'Lady_Elliot': 34.95596737726098,
#  'seventeen_years': 50.974365314869765,
#  'an_awful': 15.611271338865924,
#  'Lady_Russell': 1370.622475417512,
#  'Anne_Elliot': 69.51674910071942,
#  'Miss_Elliot': 81.92874088041013,
#  'everybody_else': 116.64359274208759,
#  'her_mistress': 10.11840289117327,
#  'Mr_Elliot': 154.42250147754137,
#  'Mr_Shepherd': 153.50875886524824,
#  'anybody_else': 167.7955535959572,
#  'reference_to': 10.087650616363232,
#  'an_honest': 22.111184865066534,
#  'descend_into': 19.58505623967444,
#  'Mrs_Clay': 287.0445438704621,
#  'Miss_Anne': 13.81699361008088,
#  'their_fathers': 21.038472507920055,
#  'an_example': 17.82878147222756,
#  'Admiral_Croft': 1020.8710564930301,
#  'Mrs_Croft': 207.37305091376516,
#  'walked_along': 11.422274896105895,
#  'Frederick_Wentworth': 23.252406376898783,
#  'either_side': 19.363312306866,
#  'Captain_Wentworth': 976.2658980080998,
#  'eldest_son': 39.758333601208655,
#  'removed_from': 14.303712270151498,
#  'good_humour': 57.21881939304219,
#  'The_Crofts': 10.249618801378945,
#  'startled_by': 14.177175563185834,
#  'most_important': 33.80560735175321,
#  'replied_Anne': 13.874444726962713,
#  'at_Uppercross': 13.940248018586367,
#  'Great_House': 1177.944761904762,
#  'left_alone': 14.135748364627752,
#  'Mr_Musgrove': 32.388661211129296,
#  'Miss_Musgroves': 227.52303763499037,
#  'Mrs_Musgrove': 156.7704816523293,
#  'flower_-': 13.524789502460361,
#  'grown_up': 12.21891287320147,
#  'their_faces': 22.656977192617102,
#  'surprised_at': 14.056416752074586,
#  'ere_long': 33.88236905544598,
#  'anything_else': 74.81068120893052,
#  'quite_different': 19.349238133975785,
#  'their_sakes': 16.878072078710716,
#  'twentieth_year': 185.54485448544855,
#  'on_board': 34.25698443940126,
#  'eight_years': 61.89744359662757,
#  '-_bone': 13.499174370826912,
#  'their_heads': 21.62117992564767,
#  'Your_sister': 24.014484311898105,
#  'dressing_-': 29.645245677110086,
#  'up_stairs': 14.51249618660972,
#  'waited_till': 12.054520291606565,
#  'third_part': 80.67867146551659,
#  'Phoo_!': 23.962840259614456,
#  'dear_fellow': 20.631226021684736,
#  'good_cheer': 58.85364280427197,
#  'Mrs_Harville': 84.63892670628489,
#  '"_Ay': 18.457497511961623,
#  'fifteen_years': 52.05892627901593,
#  'Charles_Hayter': 2649.2943696450425,
#  'came_near': 11.627278418555207,
#  'Her_husband': 21.943829394649068,
#  'two_hundred': 34.52901130958137,
#  'Dr_Shirley': 1086.3785682916118,
#  'went_up': 10.892879248012838,
#  'within_reach': 18.479083248670293,
#  '-_yard': 16.037591923682506,
#  'turn_back': 10.596023199431151,
#  'walking_along': 19.12445108751675,
#  'leaning_against': 23.700128657852236,
#  'trodden_under': 72.24544392523364,
#  'under_foot': 22.229367361610354,
#  'Louisa_Musgrove': 189.52528348145879,
#  'provoke_me': 16.48946779010239,
#  'Very_good': 10.325200491977538,
#  'good_humoured': 26.15717457967643,
#  'Captain_Harville': 475.42275075075077,
#  'at_Lyme': 20.29311726486752,
#  'earnest_desire': 32.790084835630964,
#  'Captain_Benwick': 811.8267953667954,
#  'an_officer': 10.895366455250176,
#  'place_where': 29.883357272686972,
#  '-_coat': 13.073963185711682,
#  'an_introduction': 10.895366455250176,
#  'preceding_evening': 48.9411997467553,
#  'an_agony': 15.202836914302571,
#  'catching_hold': 135.5294762217839,
#  'raised_up': 20.91745260416373,
#  'could_scarcely': 17.38407263731939,
#  'passed_along': 16.544168004280362,
#  'leaning_over': 33.66056062742769,
#  't_talk': 11.570517138152972,
#  'Camden_Place': 11505.506976744186,
#  'straight_forward': 11.997691337666117,
#  'same_hour': 12.921683411398027,
#  '-_glasses': 16.35444404375526,
#  'poring_over': 41.31068804275217,
#  'thirty_feet': 12.120752621435336,
#  'Colonel_Wallis': 967.3744677153037,
#  'Mrs_Wallis': 54.178544833326036,
#  '-_haired': 60.68359500446031,
#  'at_length': 17.88998495718584,
#  'carried_away': 68.93771731236752,
#  'greater_than': 48.182171075546755,
#  'Miss_Carteret': 320.0936853002071,
#  'contact_with': 11.025512569085398,
#  'Lady_Dalrymple': 1027.2774086378738,
#  'Laura_Place': 777.3991200502828,
#  'be_established': 13.256107901092253,
#  'Mrs_Smith': 111.99977591965032,
#  'Westgate_Buildings': 8589.180555555555,
#  'buried_him': 10.212015743068294,
#  'at_liberty': 14.03136075073399,
#  'human_nature': 43.51094068810244,
#  'five_thousand': 37.910597744077265,
#  'whose_names': 20.29106718070708,
#  'her_ladyship': 34.12236790377201,
#  '-_maker': 26.620220608017217,
#  'old_gentleman': 27.054312400201237,
#  'almost_entirely': 36.10558657179347,
#  'lower_part': 15.927465187754331,
#  'staring_at': 25.04597894006017,
#  'an_oath': 44.98731955716202,
#  'wiser_than': 29.373088249263798,
#  'prejudice_against': 39.177763699714916,
#  'both_sides': 99.67073029216844,
#  'my_soul': 16.443509373671976,
#  'rejoice_over': 10.11690319414339,
#  'same_instant': 25.162444780283654,
#  'every_one': 14.671392435905245,
#  'their_seats': 12.658554059033037,
#  'their_mouths': 26.497142818484406,
#  'short_silence': 19.427041120849434,
#  '-_blooded': 17.4695197740113,
#  'general_character': 10.833526031812768,
#  'fifty_pounds': 35.380799816923165,
#  'be_saved': 13.4097233300756,
#  'threw_himself': 10.029912473712379,
#  'some_moments': 21.006148097826088,
#  'exclaimed_Mrs': 12.149128235351897,
#  'compassion_on': 13.01248600742343,
#  'an_explanation': 16.343049682875264,
#  'our_hearts': 14.94420279348509,
#  'minutes_afterwards': 22.216989096657148,
#  'make_haste': 50.38463418608441,
#  "'_n": 22.533063472289214,
#  "n_'": 16.09504533734944,
#  'rising_sun': 13.065738461700983,
#  '-_faced': 42.60858481466171,
#  'an_atonement': 89.61132859823739,
#  'atonement_for': 24.315805643301744,
#  '"_Look': 10.09252327008739,
#  'Look_here': 26.311681865240885,
#  ...}

# %%
tokenized_sentence = "Jon lives in New York City".split()

# %%
tokenized_sentence
# Out:
# ['Jon', 'lives', 'in', 'New', 'York', 'City']

# %%
bigram[tokenized_sentence]
# Out:
# ['Jon', 'lives', 'in', 'New_York', 'City']

# %% [markdown]
# #### Preprocess the corpus

# %%
# as in Maas et al. (2001):
# - leave in stop words ("indicative of sentiment")
# - no stemming ("model learns similar representations of words of the same stem when data suggests it")
lower_sents = []
for s in gberg_sents:
    lower_sents.append([w.lower() for w in s if w.lower() not in list(string.punctuation)])

# %%
lower_sents[0:5]
# Out:
# [['emma', 'by', 'jane', 'austen', '1816'],
#  ['volume', 'i'],
#  ['chapter', 'i'],
#  ['emma',
#   'woodhouse',
#   'handsome',
#   'clever',
#   'and',
#   'rich',
#   'with',
#   'a',
#   'comfortable',
#   'home',
#   'and',
#   'happy',
#   'disposition',
#   'seemed',
#   'to',
#   'unite',
#   'some',
#   'of',
#   'the',
#   'best',
#   'blessings',
#   'of',
#   'existence',
#   'and',
#   'had',
#   'lived',
#   'nearly',
#   'twenty',
#   'one',
#   'years',
#   'in',
#   'the',
#   'world',
#   'with',
#   'very',
#   'little',
#   'to',
#   'distress',
#   'or',
#   'vex',
#   'her'],
#  ['she',
#   'was',
#   'the',
#   'youngest',
#   'of',
#   'the',
#   'two',
#   'daughters',
#   'of',
#   'a',
#   'most',
#   'affectionate',
#   'indulgent',
#   'father',
#   'and',
#   'had',
#   'in',
#   'consequence',
#   'of',
#   'her',
#   'sister',
#   's',
#   'marriage',
#   'been',
#   'mistress',
#   'of',
#   'his',
#   'house',
#   'from',
#   'a',
#   'very',
#   'early',
#   'period']]

# %%
lower_bigram = Phraser(Phrases(lower_sents))

# %%
lower_bigram.phrasegrams # miss taylor, mr woodhouse, mr weston
# Out:
# {'two_daughters': 11.080802900992637,
#  'her_sister': 16.93971298099339,
#  'very_early': 10.516998773665177,
#  'her_mother': 10.70812618607742,
#  'long_ago': 59.22644201533601,
#  'more_than': 28.529926612065935,
#  'had_been': 21.583193129694834,
#  'an_excellent': 37.41859680854167,
#  'sixteen_years': 131.42913000977518,
#  'miss_taylor': 420.4340982546865,
#  'mr_woodhouse': 104.19907841850323,
#  'very_fond': 24.185726346489627,
#  'passed_away': 11.751473221742694,
#  'too_much': 30.363090173835406,
#  'did_not': 10.846196223896685,
#  'any_means': 14.294148100212627,
#  'after_dinner': 18.60737125272944,
#  'mr_weston': 91.63290824201266,
#  'five_years': 37.66428596665674,
#  'years_old': 48.59909444619029,
#  'seven_years': 50.3345604292756,
#  'each_other': 71.31277029783762,
#  'well_informed': 14.185028016786626,
#  'a_mile': 11.700110753652233,
#  'difference_between': 207.86784241868986,
#  'mrs_weston': 180.6778969011602,
#  'could_not': 10.213333164207082,
#  'having_been': 10.723750443105281,
#  'sixteen_miles': 105.040625,
#  'miles_off': 32.99182066941624,
#  'at_hartfield': 25.55599247874428,
#  'her_husband': 26.67842743680748,
#  'in_spite': 13.346436370855669,
#  'emma_could': 10.886088052836328,
#  'every_body': 39.26110856993498,
#  'no_means': 26.766046928639682,
#  'able_to': 10.854471217684639,
#  'very_much': 15.431918564512344,
#  'have_been': 17.20622462716941,
#  'great_deal': 110.16914388000741,
#  'agree_with': 13.12648342622773,
#  'good_humoured': 149.07455772926625,
#  'for_ever': 10.477844500702483,
#  'three_times': 38.14441525690869,
#  'my_dear': 26.34325710301932,
#  'last_night': 23.230537949447992,
#  'doubt_whether': 19.564378663784144,
#  'anywhere_else': 15.306466302367943,
#  'i_am': 16.330282814272387,
#  'very_glad': 16.952537612290154,
#  'am_sure': 60.92067362479539,
#  'very_pretty': 18.02785881936292,
#  'be_able': 10.915272046078586,
#  'immediately_afterwards': 37.530798337572115,
#  'mr_knightley': 179.56587130817343,
#  'sensible_man': 13.469145146927872,
#  'intimate_friend': 20.19472630173565,
#  'connected_with': 16.865113476644794,
#  'elder_brother': 14.417929653989134,
#  'than_usual': 27.96484669654346,
#  'brunswick_square': 2374.2341399607585,
#  'some_time': 11.678170286892607,
#  'poor_isabella': 43.036881601877866,
#  'am_afraid': 24.40430621044607,
#  'moonlight_night': 13.233464566929133,
#  'look_at': 10.167669372199262,
#  'vast_deal': 58.665223012281835,
#  'an_hour': 40.46461919025373,
#  'pretty_well': 13.991375757171792,
#  'tolerably_well': 13.779741502021295,
#  'miss_woodhouse': 272.89637286224394,
#  'you_please': 10.458014920259812,
#  'any_rate': 81.39444780766237,
#  'very_true': 13.110718065819087,
#  ',"_said': 35.208800203215695,
#  'my_dearest': 15.989439634668441,
#  'so_much': 16.689081989684137,
#  'much_less': 18.956871177506912,
#  'any_body': 20.81402827327549,
#  'has_been': 28.01515665997839,
#  'been_used': 13.60480451219398,
#  'dear_emma': 26.724453867413775,
#  'every_thing': 26.81358385148003,
#  'very_sorry': 20.451631026452166,
#  'turned_away': 18.47583754119931,
#  'divided_between': 32.867992177314214,
#  'how_much': 13.223145529540588,
#  'four_years': 17.08789651812486,
#  'years_ago': 157.92138920022725,
#  'any_thing': 34.60353767883287,
#  'oh_dear': 13.071010293556995,
#  'need_not': 12.811033130226706,
#  'ever_since': 42.54639154544724,
#  'leave_off': 10.456551581109641,
#  'match_making': 19.514707779641338,
#  'young_lady': 46.68694722651542,
#  'depend_upon': 79.94054343302217,
#  'more_likely': 10.63926988816206,
#  'have_done': 12.079550287766299,
#  ',"_rejoined': 10.722990216928967,
#  'mr_elton': 139.40875576036868,
#  'any_longer': 15.647026370007673,
#  'very_well': 12.39111202663676,
#  'young_man': 24.28633425456425,
#  'dine_with': 13.166381552143315,
#  'much_better': 10.49785543468346,
#  'i_dare': 13.033485583230483,
#  'dare_say': 119.19759719744675,
#  'take_care': 74.57127010537992,
#  'chapter_ii': 279.33240997229916,
#  'entering_into': 14.764128843338213,
#  'never_seen': 13.026399306383945,
#  'mrs_churchill': 72.70198534025822,
#  'refrain_from': 13.332613486117234,
#  'at_once': 18.772289267502117,
#  'three_years': 36.12160535692111,
#  'mother_s': 10.43349082727472,
#  'twenty_years': 82.70010934937123,
#  'according_to': 11.428224398751397,
#  'had_begun': 11.498896738107863,
#  'passed_through': 29.981417521047756,
#  'its_being': 15.035551583602627,
#  'deal_better': 18.324491856239064,
#  'belonging_to': 10.007375856554956,
#  'mr_frank': 51.133858947969415,
#  'frank_churchill': 1615.1350106048417,
#  'mrs_perry': 23.55271814235942,
#  'miss_bates': 368.52784388923357,
#  'a_few': 11.993654742645493,
#  'few_days': 34.438895740442085,
#  'i_suppose': 11.320989637575266,
#  'very_handsome': 18.2932039275267,
#  'an_irresistible': 10.743649616890554,
#  'good_sense': 15.484518577039912,
#  'had_already': 11.16134847902147,
#  'long_enough': 14.424561747959498,
#  'at_randalls': 24.914802703291915,
#  'few_weeks': 130.17082616179002,
#  'no_longer': 37.27164862774777,
#  'mr_perry': 95.9153455928979,
#  'chapter_iii': 294.85087719298247,
#  'donwell_abbey': 737.1720986902224,
#  'card_table': 52.05489116407124,
#  'drawing_room': 219.7798692292451,
#  'thrown_away': 13.991597804637394,
#  'mrs_goddard': 292.6791161249692,
#  'an_invitation': 13.178876863385748,
#  'mrs_bates': 54.6665437867962,
#  'those_who': 14.383248820933867,
#  'as_possible': 10.515284953239568,
#  'young_ladies': 111.39207280187264,
#  'old_fashioned': 181.0280072171398,
#  'coming_back': 10.421002047913246,
#  'goddard_s': 30.051494868668044,
#  'found_herself': 10.853751672615102,
#  's_sake': 27.30490695465855,
#  'much_pleased': 12.52905813538587,
#  'miss_smith': 148.87785876781652,
#  'harriet_smith': 171.76079313432186,
#  'several_years': 16.071496876195333,
#  'pretty_girl': 36.100742261151815,
#  'blue_eyes': 33.95451351272216,
#  'due_time': 19.500628497333537,
#  'its_own': 10.339536241447126,
#  'an_egg': 16.473596079232184,
#  'better_than': 40.469036729734746,
#  'body_else': 37.603287294006286,
#  'much_more': 10.196735265430883,
#  'little_girl': 33.82044741555345,
#  'at_last': 25.084119133118794,
#  'chapter_iv': 252.72932330827066,
#  'every_respect': 10.88373348044036,
#  'guided_by': 22.059348262898627,
#  'different_sort': 13.93659398034398,
#  'abbey_mill': 1868.349974266598,
#  'good_deal': 34.9886756082219,
#  'very_happy': 10.609415283099846,
#  'mrs_martin': 10.98244722368445,
#  'drink_tea': 29.381993006993007,
#  'large_enough': 10.328337316490268,
#  'had_taken': 10.546895054673817,
#  'mr_martin': 92.3345987295168,
#  'three_miles': 15.396834283387623,
#  'thing_else': 11.724101848622253,
#  'very_obliging': 23.82930511612031,
#  'on_purpose': 10.243903158363866,
#  'very_clever': 19.348581077191703,
#  'miss_nash': 312.88118939883645,
#  'does_not': 11.755881647050003,
#  'oh_yes': 23.31216733177377,
#  'very_entertaining': 15.091893240209528,
#  'soon_as': 10.478935314421708,
#  'have_seen': 12.7295316573734,
#  'on_horseback': 51.18947502009391,
#  'their_families': 33.21807400900406,
#  'no_doubt': 34.59455647601341,
#  'very_respectable': 10.061262160139686,
#  'respectable_young': 26.124093264248703,
#  'very_odd': 23.337979237437416,
#  'perfectly_right': 15.182023486901535,
#  'six_years': 29.166464467922708,
#  'years_hence': 17.92215409224207,
#  'young_woman': 28.125317800019307,
#  'very_desirable': 13.719902945645027,
#  'dear_miss': 23.615690866510537,
#  'thirty_years': 70.51678321678321,
#  'can_afford': 24.00055535354203,
#  'good_luck': 50.83824661023695,
#  'acquainted_with': 25.94043153278337,
#  'harriet_s': 10.391255619709804,
#  'next_day': 31.552600854623535,
#  'an_opportunity': 39.48568132393281,
#  'few_yards': 121.49277108433735,
#  'robert_martin': 1822.180470288428,
#  'few_minutes': 306.2525246213068,
#  'been_able': 15.563975922210219,
#  'should_happen': 19.56851425106125,
#  'compared_with': 15.206045360968936,
#  'well_bred': 56.08034332217969,
#  'an_old': 10.093145123027888,
#  'old_man': 11.391492291491135,
#  'more_valuable': 16.92611118571237,
#  ',"_replied': 67.1468742897922,
#  'very_bad': 14.502720230831981,
#  'deal_too': 11.983244206773618,
#  'no_more': 15.083521866761401,
#  'good_humour': 64.86757782273477,
#  'very_agreeable': 20.12252432027937,
#  'fixed_on': 10.217254086671971,
#  'same_time': 17.450483557641775,
#  'pleasing_young': 22.392079940784605,
#  'chapter_v': 186.22160664819944,
#  'very_differently': 45.27567972062859,
#  'twelve_years': 44.13664813761106,
#  'very_neatly': 21.559847486013613,
#  'ten_years': 33.477231228905,
#  'being_able': 13.768546669336779,
#  'have_spoken': 11.097204476268063,
#  'yes_,"': 21.319081141349894,
#  'thank_you': 18.72934857104649,
#  'could_possibly': 29.277491471292734,
#  'grown_up': 13.110499863891405,
#  'any_harm': 11.88333382435259,
#  'an_angel': 20.854313507945204,
#  'excuse_me': 17.305246066110467,
#  'an_end': 17.098710216167333,
#  'many_years': 18.58677200012534,
#  ',"_cried': 33.94160588989982,
#  'much_obliged': 42.51023467141318,
#  'mrs_john': 22.74667029354493,
#  'john_knightley': 169.26886715265277,
#  'be_satisfied': 11.946063802781145,
#  'ill_humour': 26.63236200369751,
#  'i_assure': 12.733255394756087,
#  'assure_you': 28.436400120257012,
#  'soon_afterwards': 78.59594937705434,
#  'chapter_vi': 126.36466165413533,
#  'most_agreeable': 26.48430728824688,
#  'no_scruple': 22.498995969001474,
#  'infinitely_superior': 270.28545901273174,
#  'am_glad': 16.09346987631334,
#  'very_interesting': 16.768770266899477,
#  'no_sooner': 38.5355143724387,
#  'don_t': 258.7786954087346,
#  't_pretend': 21.455106382978723,
#  'why_should': 17.72050499445061,
#  'cannot_imagine': 46.70634553033812,
#  'back_again': 17.518775026164434,
#  'an_artist': 15.443996324280171,
#  'higher_than': 44.04157170252713,
#  'ten_times': 32.73329275715155,
#  'mr_john': 14.765003852281561,
#  'must_allow': 15.128011144449207,
#  'sitting_down': 16.50978251971512,
#  'must_confess': 11.475103270125821,
#  'depended_on': 19.196053132535216,
#  'after_breakfast': 10.176820020576766,
#  'sooner_than': 15.493715063361527,
#  'at_home': 14.817173413852018,
#  'at_least': 40.005129511612694,
#  'yes_indeed': 13.32791435368755,
#  'replied_emma': 15.977524691150556,
#  'can_hardly': 23.71390376951493,
#  'am_persuaded': 13.9008842237933,
#  'beg_your': 41.769363228062694,
#  'your_pardon': 35.83165749517416,
#  'tell_me': 10.695563383577781,
#  'entered_into': 56.41577688104846,
#  'older_than': 56.23201606007658,
#  'run_away': 37.8745366554535,
#  'have_borne': 10.466681494661922,
#  'good_opinion': 13.341832563897801,
#  'good_natured': 159.13709037599173,
#  'emma_felt': 16.140511741705346,
#  'no_difficulty': 11.983675747699731,
#  'let_us': 31.76961003819016,
#  'cried_emma': 13.884714320584314,
#  'bond_street': 172.37435897435896,
#  'some_weeks': 11.200682740440154,
#  'next_morning': 78.14689256415173,
#  'without_ceremony': 10.070807949665435,
#  'dear_sir': 14.956604215456675,
#  'sat_down': 55.2769805500231,
#  'depends_upon': 17.98662227242999,
#  'has_happened': 15.991242753687029,
#  'presently_added': 18.897863568215893,
#  'could_afford': 15.539591627070758,
#  'does_seem': 12.372250907417822,
#  'few_moments': 372.31655654877574,
#  'nobody_knows': 29.65198853194148,
#  'very_likely': 27.439805891290053,
#  'good_tempered': 28.203294705536855,
#  'all_probability': 12.433560319461959,
#  'no_harm': 22.746237682946546,
#  'cannot_help': 18.923655657158456,
#  'very_different': 16.46388353477403,
#  'common_sense': 161.56643879512924,
#  'an_hundred': 29.194395140414738,
#  'every_man': 11.997412827968947,
#  'less_than': 36.5391922539134,
#  'large_fortune': 31.79160591133005,
#  'no_use': 12.936922682175846,
#  'these_words': 23.297961459941245,
#  'twenty_thousand': 74.70393983612077,
#  'thousand_pounds': 447.518052808119,
#  'walked_off': 10.460621861989791,
#  'cast_down': 13.997424310193253,
#  'its_effects': 41.35193876156195,
#  'deal_more': 10.514102007124858,
#  'longer_than': 18.062953068815595,
#  'perfectly_satisfied': 88.02506546950993,
#  'three_hundred': 46.95431447257635,
#  'well_known': 14.092917445249052,
#  'destin_d': 66.58969843715606,
#  'looking_at': 11.578307624593489,
#  'next_moment': 24.112003750805837,
#  'ready_wit': 64.00444303395747,
#  'very_pleasant': 11.433252454704187,
#  'an_idea': 13.222953374634528,
#  'arrive_at': 10.99182472204055,
#  'nobody_could': 14.343345036944983,
#  'have_chosen': 11.81866516078164,
#  'without_exception': 49.916178533124324,
#  'her_cheeks': 10.713032768823975,
#  'sit_down': 35.66504947879112,
#  'reason_why': 17.06388019290972,
#  'could_hardly': 23.030990847938746,
#  'an_offering': 10.631590689986872,
#  'can_easily': 13.582403838136347,
#  'dear_mother': 13.628181044152825,
#  'those_things': 14.86148076986059,
#  'next_week': 53.87957922858575,
#  'taken_away': 32.39398354768761,
#  'stay_longer': 35.24360408220327,
#  'three_days': 36.85541434763651,
#  'cannot_bear': 14.75548726953468,
#  'o_clock': 157.91912099014903,
#  'ask_whether': 13.90355382441143,
#  'ran_away': 14.924370991613221,
#  'who_lived': 11.874990409543708,
#  'never_mind': 14.649399814275704,
#  'good_fortune': 17.88894692751195,
#  'jane_fairfax': 878.2658066636538,
#  'nothing_else': 30.0085928868752,
#  'present_instance': 15.177453341360627,
#  'once_more': 21.75850683894797,
#  'still_greater': 11.400499332652902,
#  'here_comes': 16.697963238946844,
#  'turned_back': 27.419992871324965,
#  'will_bring': 11.542472822887643,
#  'each_side': 20.499637888317135,
#  'still_remained': 12.13368361944489,
#  'she_hoped': 15.572051565559542,
#  'ten_minutes': 194.73592734674705,
#  'most_favourable': 11.684253215403036,
#  'ten_days': 15.98003268459367,
#  'little_ones': 58.130349583162364,
#  'mr_wingfield': 102.72224108658745,
#  'passed_over': 21.874777302895755,
#  'yes_sir': 17.048013524936604,
#  'sir_,"': 14.215621316157257,
#  'cannot_deny': 32.95392156862745,
#  'talking_about': 19.03295977350478,
#  'never_forget': 19.811797243380486,
#  'cannot_tell': 16.07682643742666,
#  'two_years': 11.95816852658443,
#  'indeed_!--': 14.904334331005431,
#  'dear_madam': 86.09887295081968,
#  "madam_,'": 23.782783018867924,
#  'most_amiable': 20.908663648615956,
#  ',"_observed': 11.457441601650128,
#  'five_times': 11.197490422519571,
#  'our_lives': 17.148517657729155,
#  'think_differently': 11.912463083284111,
#  'grow_up': 10.504597456351943,
#  'shake_hands': 50.539953555975075,
#  'how_long': 12.747548678067647,
#  'perfectly_convinced': 72.51995685005394,
#  'tells_me': 12.055904371165491,
#  'bad_cold': 12.931807252091948,
#  'far_off': 31.65388598534036,
#  'am_sorry': 25.55609823252787,
#  'mrs_campbell': 25.553929487788654,
#  'ah_!"': 17.216148693638065,
#  'an_interval': 15.772591990754218,
#  'perfectly_well': 10.91605036682757,
#  'ill_judged': 16.56130074179509,
#  'can_tell': 10.59868410018371,
#  'morrow_morning': 21.336820698491813,
#  'own_feelings': 10.440997949569127,
#  'sore_throat': 237.47777450691785,
#  'well_satisfied': 14.614877350628644,
#  'looked_at': 11.997174544178405,
#  'well_pleased': 18.617849272032448,
#  'set_forward': 28.09422851055694,
#  'eldest_daughter': 81.36551909628832,
#  'short_time': 10.057824159586259,
#  ',"_continued': 40.15998883792505,
#  'dining_room': 272.7268377253814,
#  'enter_into': 32.02961835848166,
#  'half_hour': 17.306134513071832,
#  'gone_through': 10.232695965811631,
#  'turn_away': 24.324951021984198,
#  'own_sake': 10.579228284294226,
#  'an_effort': 12.355197059424137,
#  ',"_repeated': 15.364284489928071,
#  'several_times': 99.00042075736326,
#  'great_curiosity': 12.09281966721631,
#  'upper_end': 46.569735221674875,
#  'an_odd': 25.47463311221472,
#  'dearest_emma': 38.814087759815244,
#  'continued_mrs': 12.451436979718675,
#  'go_home': 10.007173127288121,
#  'judge_between': 14.60799652325076,
#  'hardly_knew': 28.982276298141407,
#  'set_off': 12.027500784416544,
#  'got_home': 12.614899339653833,
#  'most_extraordinary': 42.018372140007074,
#  'an_inch': 63.14878497039003,
#  'at_ease': 15.972495299215172,
#  'three_quarters': 46.190502850162865,
#  'smith_!--': 17.971662805204062,
#  'extremely_sorry': 71.27550459436111,
#  'many_weeks': 19.40231403686553,
#  'madam_,"': 12.063363994045087,
#  'extremely_well': 22.29075831209327,
#  'without_knowing': 31.14924319315123,
#  'poor_harriet': 13.183234482788675,
#  'an_instant': 42.54170416065454,
#  'thirty_thousand': 40.06847682119205,
#  'somebody_else': 161.2778888444622,
#  'worth_having': 20.026280947967695,
#  'poor_girl': 25.65660249342719,
#  'laugh_at': 10.684790511927686,
#  'knowing_what': 10.324563551972247,
#  'many_days': 13.4746779374137,
#  'whole_party': 20.8072769791595,
#  'six_weeks': 16.914565278166062,
#  'too_late': 82.78464324520102,
#  'her_companions': 11.248284965327484,
#  'drew_near': 127.06472006778336,
#  'three_months': 79.13813268974363,
#  'other_side': 27.098664528007962,
#  'an_unnatural': 18.169407440329614,
#  'get_rid': 208.69330573907504,
#  'watering_place': 80.21132175526978,
#  'while_ago': 12.961199989717313,
#  'at_weymouth': 40.30335731414868,
#  'present_occasion': 30.82190524707081,
#  'their_hearts': 16.688506081078597,
#  'break_through': 10.134403108825648,
#  'burst_forth': 46.35182980729565,
#  'young_men': 26.25825955394037,
#  'nobody_else': 79.07196941851063,
#  'something_else': 35.09762973791375,
#  'walking_together': 11.011028608866566,
#  'burst_out': 10.336378346321213,
#  'mrs_cole': 133.52975449561694,
#  'mr_cole': 75.77870244092516,
#  'miss_fairfax': 253.16112835175562,
#  'extremely_happy': 17.87106969325516,
#  'ma_am': 180.33443656689536,
#  's_handwriting': 11.116226942015139,
#  'without_seeming': 22.511217769840382,
#  'colonel_campbell': 852.6827205882353,
#  'those_days': 22.563533110519458,
#  'mrs_dixon': 66.64348656190336,
#  'mr_dixon': 99.22034650409013,
#  'miss_campbell': 69.78477508650519,
#  'caught_hold': 22.46057555238774,
#  'four_months': 35.22349653606567,
#  'may_guess': 12.384068773773176,
#  'running_away': 10.939329522648434,
#  'five_minutes': 138.27274480256534,
#  'nine_years': 20.394175346344422,
#  'hundred_pounds': 61.54765860771083,
#  'rather_than': 18.774125510292563,
#  'few_months': 56.654660091141764,
#  'she_wished': 13.111156859133413,
#  'without_feeling': 12.941231471550752,
#  'ill_health': 24.481922835697087,
#  'twelve_thousand': 56.81351191064545,
#  'mr_churchill': 14.856522471200662,
#  'passed_between': 18.633822336745066,
#  ",'_said": 29.904409319301955,
#  'miss_hawkins': 330.480756302521,
#  'dear_jane': 27.27885083590326,
#  'three_minutes': 10.22196466946896,
#  'have_suffered': 12.671527233246879,
#  'hour_ago': 34.58206634811038,
#  'ford_s': 13.291140908931144,
#  'looked_round': 11.112143696738173,
#  'help_thinking': 29.99553810458683,
#  'can_t': 33.88376276641461,
#  'human_nature': 30.58786058786059,
#  'brown_s': 12.276957466080978,
#  'laughed_at': 11.579174134668671,
#  'weeks_ago': 64.6472913772839,
#  'twenty_miles': 30.043399099576273,
#  'elder_sister': 19.20011424219345,
#  'driven_away': 13.818862029271502,
#  'setting_off': 15.776910506918853,
#  'little_farther': 12.063393148450245,
#  'spot_where': 30.983262494042016,
#  'front_door': 47.78138820286026,
#  'they_parted': 10.793385186242329,
#  'without_delay': 16.401030089455137,
#  'six_months': 137.41988785577402,
#  'months_ago': 32.82608577706644,
#  'leaned_back': 11.972573463935886,
#  'ill_disposed': 23.461842717543043,
#  'at_oxford': 13.739780902550686,
#  'turned_round': 11.459329950969135,
#  'pass_through': 20.61016160414778,
#  'clock_struck': 271.6146594294576,
#  '"\'_tis': 65.71456500488759,
#  'four_hours': 44.143732671822555,
#  'parlour_door': 13.546649351812462,
#  'faster_than': 38.52934433745988,
#  'musical_society': 97.72799224680989,
#  'worth_while': 32.809013467947075,
#  'kind_hearted': 22.299646174259177,
#  'mixed_with': 12.314824536333052,
#  'extremely_glad': 69.64820996891908,
#  'knew_nothing': 11.012511694448186,
#  'make_amends': 63.131237772270765,
#  'amends_for': 12.75831653909067,
#  'oftener_than': 48.954931628772556,
#  'old_woman': 16.854605854208888,
#  'just_going': 11.441554905030976,
#  'their_lives': 13.550496390619374,
#  'six_days': 24.799150037752128,
#  'may_prove': 12.11027133489724,
#  'stronger_than': 55.48225584594223,
#  'particular_friend': 18.111862154023,
#  'good_tidings': 28.459688293769013,
#  'among_themselves': 14.391206579513122,
#  'next_summer': 24.61739395788831,
#  'on_tuesday': 11.26168450442066,
#  'breaking_up': 11.204903953442072,
#  'after_tea': 10.09972289920876,
#  'perfectly_safe': 15.182023486901535,
#  'two_ladies': 10.349582404988046,
#  'same_moment': 15.167877661019073,
#  'mr_cox': 82.17779286926995,
#  ',"_added': 21.445980433857933,
#  'little_girls': 21.933442088091354,
#  'be_ashamed': 14.839124152298215,
#  'been_staying': 13.648409654861268,
#  'shut_up': 31.307093975641564,
#  'too_large': 13.11269940787182,
#  'an_elderly': 12.355197059424137,
#  'worse_than': 50.38186909777265,
#  'opposite_side': 20.550379566258513,
#  'short_pause': 83.26155963302753,
#  'large_party': 13.46015572858732,
#  'who_knows': 23.272149610357637,
#  'extremely_fond': 32.5917905623788,
#  'five_couple': 45.27680909975305,
#  'mr_william': 12.681758158837956,
#  'bow_window': 25.073932863655198,
#  'bad_news': 59.57111209570226,
#  'baked_apples': 587.9825072886297,
#  'mrs_wallis': 79.25171374929049,
#  'will_send': 14.065286062406157,
#  'william_larkins': 4596.649572649573,
#  'low_voice': 51.584448802114416,
#  'one_leg': 10.201187499351517,
#  'an_immediate': 13.305596833225993,
#  ',"_resumed': 27.879774564015314,
#  'many_times': 13.085087488088238,
#  'few_words': 11.206759868233577,
#  'no_objection': 27.457958345842616,
#  'astonished_at': 12.457401351645958,
#  'four_times': 16.708165484388754,
#  'c_.,': 484.8028846153846,
#  'few_hours': 74.55238225629792,
#  'an_extraordinary': 10.691997455270888,
#  'immediately_followed': 11.60491790701243,
#  'wait_till': 30.635873858181597,
#  'good_bye': 141.49449547184594,
#  'contrast_between': 157.76636245110822,
#  'dared_not': 11.170638889884435,
#  'three_weeks': 30.165226351126773,
#  'self_command': 129.45780554604588,
#  'mrs_elton': 115.93850995531125,
#  'maple_grove': 6513.823602484472,
#  'mr_suckling': 67.58042176749173,
#  'almost_fancy': 14.733568732497261,
#  'left_behind': 27.450387913434053,
#  'barouche_landau': 17286.685714285715,
#  'whose_name': 27.214399799798326,
#  'mr_e': 15.658878214418817,
#  'e_.,': 189.19136960600375,
#  'good_breeding': 36.8301848507599,
#  'greater_part': 15.073845233942896,
#  'drew_back': 14.116134651802138,
#  'third_time': 12.45550979515326,
#  'very_extraordinary': 11.60914864631502,
#  'better_acquainted': 12.586519658830872,
#  'have_committed': 16.059987478581785,
#  'drawing_rooms': 127.10798319327732,
#  'hardly_less': 12.215670175249684,
#  'will_shew': 11.000022831745259,
#  'little_boys': 15.381894451388742,
#  'post_office': 378.61952440550687,
#  'easily_believe': 20.68020963882876,
#  'put_forth': 11.449099051744076,
#  'mrs_bragge': 46.544657281329336,
#  'drawing_near': 17.917377398720685,
#  'great_joy': 10.054550288918538,
#  'spread_abroad': 187.66563275434243,
#  'few_lines': 41.41799014238773,
#  'good_news': 22.238991398956113,
#  'most_likely': 18.05748224198651,
#  'talk_about': 21.439425951764,
#  'tells_us': 28.49862729793018,
#  'sixty_five': 24.217828123123724,
#  'eleven_years': 15.563975922210219,
#  'your_sister': 17.156751175996334,
#  'two_hours': 15.059818488167268,
#  'two_months': 19.80765285410601,
#  'twenty_four': 24.690562341866855,
#  'door_opened': 31.97009247027741,
#  'began_talking': 12.980428544611012,
#  'mean_?"': 24.672830374194895,
#  'pretty_soon': 15.281868324424673,
#  'many_hours': 12.099988572081596,
#  'few_steps': 21.356151167168672,
#  'most_excellent': 13.620500891098397,
#  'surrounded_by': 28.432048872180452,
#  'later_than': 15.131524321620608,
#  'whole_story': 33.811825091134196,
#  'another_minute': 10.47206452506231,
#  'whole_history': 21.865274113693037,
#  'lined_with': 12.665905060395177,
#  'court_plaister': 660.5174672489082,
#  'these_things': 38.76461305007587,
#  'laid_down': 11.76806952449668,
#  'forty_years': 158.55386535221814,
#  'faint_smile': 23.553176580504516,
#  'turned_towards': 10.359757315632367,
#  'totally_different': 152.78636363636363,
#  'box_hill': 162.97043283674864,
#  'some_surprise': 20.08802185605737,
#  'may_depend': 14.385534434180963,
#  ',"_interrupted': 29.580662667390254,
#  'whatever_else': 19.41965768758576,
#  'larger_than': 18.09203994976377,
#  'were_assembled': 17.32252684721483,
#  'insisted_on': 10.828542792712174,
#  'clothed_with': 11.957873100497311,
#  'twenty_minutes': 15.956660102679514,
#  'quite_alone': 10.13378072065835,
#  'etc_.,': 3723.286153846154,
#  ',"_whispered': 25.73517652062952,
#  'shan_t': 201.14162234042553,
#  'looking_round': 16.13132441247656,
#  ',"_answered': 22.031354589620804,
#  'yes_yes': 34.423873463814296,
#  'old_age': 59.17756524475554,
#  'an_infant': 23.75999434504642,
#  'be_forgiven': 17.634665613629313,
#  'lie_down': 29.04728653844615,
#  'mrs_smallridge': 65.16252019386107,
#  'four_miles': 15.174408105939005,
#  'great_hurry': 18.475141158247137,
#  'without_waiting': 17.062642768222968,
#  'comes_back': 14.131562121366947,
#  'heightened_by': 10.935403412377095,
#  'cut_off': 148.51792396902442,
#  'trembling_voice': 11.589135556534565,
#  'time_past': 12.30314881906576,
#  'second_time': 18.99080814446207,
#  'five_hundred': 84.28815897682486,
#  'an_arrow': 13.727996732693487,
#  'presented_themselves': 11.270705264334413,
#  'at_random': 22.939460289475928,
#  'far_distant': 33.91663463386508,
#  'few_seconds': 91.11957831325302,
#  'passing_through': 17.888241729000978,
#  'domestic_happiness': 55.01309328968903,
#  'western_sun': 33.125321653435535,
#  'rose_early': 38.936482399124785,
#  'east_wind': 116.45940284649963,
#  'gone_mad': 19.017256011315414,
#  'freed_from': 28.569886041679784,
#  'sinned_against': 77.5224293267156,
#  'locked_up': 12.67923342100024,
#  'deep_sigh': 42.620033812341504,
#  'ten_thousand': 129.36153942271648,
#  'happier_than': 25.476546051708166,
#  'nay_nay': 32.48591908507611,
#  'had_formerly': 11.277764108528865,
#  'little_boy': 21.623428772358615,
#  'fancying_herself': 25.96266735324408,
#  'right_hand': 41.80066296107419,
#  'infinitely_more': 12.077009062238014,
#  'such_cases': 12.891349431818183,
#  'poor_fellow': 75.64730219711521,
#  'days_ago': 14.965593436946037,
#  'help_laughing': 15.772934643760266,
#  'draw_near': 72.06547373629091,
#  'at_intervals': 32.97547416612164,
#  'into_temptation': 11.35702218718324,
#  'sir_walter': 503.2346285714286,
#  'walter_elliot': 153.5265051903114,
#  'kellynch_hall': 1284.9824784963364,
#  'charles_musgrove': 242.12120942641172,
#  'first_year': 32.984816933402165,
#  'lady_elliot': 19.2572966730172,
#  'seventeen_years': 49.28592375366569,
#  'an_awful': 14.535525952263692,
#  'thirteen_years': 35.84430818448414,
#  'lady_russell': 757.6998474278811,
#  'anne_elliot': 67.77658011998705,
#  'miss_elliot': 75.64904190049722,
#  'everybody_else': 107.67307329941586,
#  'russell_s': 10.25826311763142,
#  'mr_elliot': 150.17351854354047,
#  'mr_shepherd': 56.76755428469306,
#  'ill_used': 18.88940691636053,
#  'anybody_else': 154.67587000287605,
#  'an_honest': 20.449981339736503,
#  'descend_into': 16.714108124533826,
#  'mrs_clay': 167.01318200947586,
#  'therefore_thus': 16.596041635939148,
#  'miss_anne': 12.80224291155311,
#  'their_fathers': 19.018975707116052,
#  'an_example': 16.847995990123824,
#  'admiral_croft': 929.5503584841243,
#  'mrs_croft': 202.2285109464654,
#  'walked_along': 10.917841095692658,
#  'frederick_wentworth': 22.56410830163348,
#  'either_side': 17.751742349011465,
#  'captain_wentworth': 617.1112879281435,
#  'eldest_son': 33.798893916540976,
#  'removed_from': 13.162771276103,
#  'startled_by': 12.543550973020787,
#  'most_important': 31.64054410542769,
#  'replied_anne': 13.57410371079436,
#  'at_uppercross': 12.847587337449994,
#  'left_alone': 14.25135144684309,
#  'mr_musgrove': 31.606843411257675,
#  'miss_musgroves': 210.81324041811845,
#  'mrs_musgrove': 152.88129737790481,
#  'piano_forte': 11524.457142857143,
#  'their_faces': 20.621617809871022,
#  'surprised_at': 13.305893084575402,
#  'ere_long': 32.47536007156702,
#  'anything_else': 72.72513938587001,
#  'quite_different': 17.841595753643947,
#  'their_sakes': 15.501767870868562,
#  'twentieth_year': 176.0098909090909,
#  'on_board': 31.77124534667287,
#  'eight_years': 64.58155526342401,
#  'their_heads': 20.78135547906293,
#  'dressing_room': 228.86168200731305,
#  'up_stairs': 14.006129941802593,
#  'waited_till': 10.336277440847356,
#  'third_part': 74.5758658942438,
#  'dear_fellow': 17.0422511407808,
#  'good_cheer': 59.6298230917065,
#  'mrs_harville': 82.53919224555735,
#  'fifteen_years': 60.35011071877431,
#  'charles_hayter': 2576.962579860055,
#  'came_near': 11.125204066571548,
#  'mansion_house': 28.44987460815047,
#  'two_hundred': 33.2713403032416,
#  'dr_shirley': 1057.7517482517483,
#  'went_up': 10.546791909362577,
#  'within_reach': 16.566742422168065,
#  'turn_back': 10.061840177671076,
#  'walking_along': 17.573893342628093,
#  'leaning_against': 24.29099376700023,
#  'trodden_under': 65.1309543032456,
#  'under_foot': 20.587370613094873,
#  'louisa_musgrove': 183.23258631132646,
#  'provoke_me': 15.67267568251514,
#  'captain_harville': 300.52135040745054,
#  'at_lyme': 20.671192760852374,
#  'earnest_desire': 31.264675485737907,
#  'sea_shore': 26.870495928941523,
#  'captain_benwick': 513.167038084151,
#  'an_officer': 10.085875150550317,
#  'place_where': 24.673747113061943,
#  'breakfast_table': 46.88913860580463,
#  'great_coat': 13.653183495244221,
#  'mean_while': 21.601999982862186,
#  'preceding_evening': 46.916408188585606,
#  'dark_blue': 10.384888690547708,
#  'an_agony': 14.366508208632718,
#  'catching_hold': 119.13870510396976,
#  'raised_up': 19.639030027092765,
#  'every_one': 13.121859438999879,
#  'could_scarcely': 16.706049522741466,
#  'passed_along': 15.774990874485061,
#  'leaning_over': 32.99075765424357,
#  't_talk': 10.789205796038152,
#  'camden_place': 304.8030226700252,
#  'straight_forward': 11.08933284457478,
#  'same_hour': 12.501907897455677,
#  'looking_glasses': 21.69513769363167,
#  'poring_over': 39.40562719812427,
#  'thirty_feet': 11.482173582995951,
#  'colonel_wallis': 919.8152027027028,
#  'at_length': 22.856646353412838,
#  'carried_away': 65.89981996296747,
#  'greater_than': 46.92382276332348,
#  'miss_carteret': 296.58529411764704,
#  'lady_dalrymple': 567.8937488267318,
#  'laura_place': 20.594798829055758,
#  'be_established': 12.514923983865962,
#  'mrs_smith': 133.20515177750605,
#  'westgate_buildings': 3878.4230769230767,
#  'at_liberty': 11.17812683597344,
#  'five_thousand': 35.86163157834745,
#  'whose_names': 17.589220303506018,
#  'her_ladyship': 32.97674284395198,
#  'ladyship_s': 11.322082996496901,
#  'old_gentleman': 24.07985483618954,
#  'their_minds': 15.501767870868562,
#  'almost_entirely': 33.52081775118424,
#  'lower_part': 14.360893094499653,
#  'staring_at': 23.08283191628515,
#  'ay_ay': 102.04655085174565,
#  'an_oath': 43.30687629076502,
#  'wiser_than': 28.37160810303864,
#  'prejudice_against': 37.30402614217892,
#  'both_sides': 93.4670833729442,
#  'my_soul': 16.066751210923982,
#  'same_instant': 24.469546226644017,
#  'their_seats': 12.91813989239047,
#  'their_mouths': 24.960473690381587,
#  'short_silence': 17.742932551319647,
#  'fifty_pounds': 33.29484921857803,
#  'be_saved': 12.820166032252938,
#  'hard_hearted': 30.946447752033144,
#  'some_moments': 21.245165972189707,
#  'exclaimed_mrs': 11.847730944338377,
#  'compassion_on': 12.135435888384333,
#  'an_explanation': 15.443996324280171,
#  'our_hearts': 17.06646733400796,
#  'minutes_afterwards': 21.366081045290017,
#  'make_haste': 69.71776454772422,
#  'n_t': 110.43069461827284,
#  'rising_sun': 11.4529037631559,
#  'an_atonement': 83.74078006943027,
#  'atonement_for': 20.65632201567061,
#  'next_instant': 11.76765535349606,
#  'she_doted': 14.810751266798855,
#  'god_forbid': 46.144377261328756,
#  'i_ll': 11.175027960975982,
#  'll_answer': 13.013882743362831,
#  'market_place': 39.58480813896431,
#  'poured_out': 41.589583712234585,
#  'at_norland': 17.421005219837852,
#  'many_generations': 16.534145874894104,
#  'seven_thousand': 31.259095392419333,
#  'mr_dashwood': 10.190698520494784,
#  'john_dashwood': 157.761220299208,
#  'four_thousand': 51.45229768371372,
#  'three_thousand': 26.103242228789615,
#  'mrs_dashwood': 149.97722901761674,
#  'miss_dashwoods': 254.21596638655464,
#  'edward_ferrars': 135.88635597978663,
#  'younger_brother': 31.67883135242683,
#  'few_miles': 14.237434111445785,
#  'replied_elinor': 38.56234426453405,
#  'mrs_ferrars': 170.42505281471358,
#  'barton_park': 511.6875679594056,
#  'from_whence': 15.950059078483806,
#  'barton_cottage': 104.5866897147796,
#  'sir_john': 127.78658844235846,
#  'at_barton': 22.230656741205607,
#  'lady_middleton': 500.3819045606168,
#  'be_fulfilled': 13.72604565972396,
#  'their_arrival': 11.398358728579826,
#  'present_case': 20.32458969190901,
#  'mrs_jennings': 317.3131418135843,
#  'colonel_brandon': 1667.5199218750001,
#  'now_therefore': 11.124642048311067,
#  'ill_natured': 147.80960912052117,
#  'blue_sky': 51.839321414291426,
#  'rose_up': 34.00644003284102,
#  'at_allenham': 10.99182472204055,
#  'miss_dashwood': 131.14315726290516,
#  'cried_marianne': 25.079165380261397,
#  'mr_willoughby': 36.686514673781225,
#  'miss_marianne': 20.916503563450696,
#  'aye_aye': 468.90135,
#  'have_erred': 17.591061335566256,
#  'pronounce_him': 17.59389669411188,
#  'by_reason': 10.359210631680098,
#  'an_everlasting': 33.79199195739935,
#  'seven_days': 82.77954431228012,
#  'by_accident': 16.659403636043233,
#  'went_out': 11.679230644951586,
#  'won_t': 217.3954908123791,
#  'miss_williams': 72.63313325330132,
#  'laughed_heartily': 104.9677307425399,
#  'considerable_time': 11.403428752365372,
#  'two_sides': 12.986418686513664,
#  'at_delaford': 13.19018966644866,
#  'two_thousand': 23.96682269843838,
#  'seven_hundred': 63.020873840342205,
#  'can_possibly': 14.130761757067319,
#  'burst_into': 13.516455983337801,
#  'turning_round': 21.605116375400833,
#  'mr_ferrars': 41.4839819772757,
#  'combe_magna': 18907.3125,
#  'mrs_palmer': 135.40263936386714,
#  'mr_palmer': 100.05413092849425,
#  'without_ceasing': 82.00515044727568,
#  'stared_at': 13.489966704322493,
#  't_think': 10.296676867200363,
#  'miss_steeles': 406.7455462184874,
#  'most_beautiful': 16.30563694985349,
#  'human_beings': 191.52706552706553,
#  'sugar_plums': 5662.879802955666,
#  'two_boys': 13.239400868718477,
#  'miss_steele': 243.16309828279137,
#  'lucy_steele': 285.9328922495274,
#  'i_m': 16.271042011107397,
#  'm_sure': 102.49120766084592,
#  'robert_ferrars': 95.96098334655036,
#  'mr_pratt': 85.6018675721562,
#  'at_longstaple': 16.48773708306082,
#  'poor_edward': 12.172840599071295,
#  'their_names': 14.302226309432305,
#  'latter_end': 42.203822544642854,
#  'i_ve': 13.517866465271059,
#  'lifted_up': 72.07416702839072,
#  'third_day': 33.791406108919496,
#  'starting_up': 11.47168738090498,
#  't_know': 12.457577307748522,
#  'returned_home': 12.907254322620558,
#  'berkeley_street': 1449.9725490196079,
#  'conduit_street': 203.71515151515152,
#  'lit_up': 36.13581524985069,
#  'as_follows': 14.278650094398992,
#  'having_received': 11.384803552611773,
#  'who_cares': 12.52589229028073,
#  'miss_grey': 10.25064380590946,
#  'fifty_thousand': 20.373801773487482,
#  'why_don': 12.795415425355843,
#  'thousand_times': 12.063627430036316,
#  'walked_across': 13.91218569999655,
#  'fourteen_years': 15.563975922210219,
#  'your_sakes': 32.49059753954306,
#  'bartlett_s': 10.18987469684721,
#  'dressing_gown': 509.28787878787875,
#  'wild_beasts': 105.23994307400379,
#  'miss_morton': 267.59575409111017,
#  'six_hundred': 132.00427053900353,
#  'harley_street': 1540.5958333333335,
#  'most_high': 22.2500544936901,
#  'filled_with': 14.087588281459942,
#  'two_thirds': 42.47641112047178,
#  'public_school': 43.03841229193341,
#  ",'_says": 42.67564803385647,
#  'fell_upon': 13.94880910923142,
#  's_office': 12.330604675176458,
#  'yes_ma': 15.105834768931167,
#  'come_near': 11.571024613341857,
#  'give_ear': 35.78134979774324,
#  'reminds_me': 14.19917625937269,
#  'ten_guineas': 26.425314465408803,
#  'south_east': 17.11383597097883,
#  'mr_harris': 85.6018675721562,
#  'quicker_than': 12.238732907193139,
#  'bent_over': 11.258750628035505,
#  'justified_by': 11.526506299532615,
#  'from_thence': 27.334646896223614,
#  'latter_days': 29.77529527559055,
#  'sprung_up': 24.090543499900456,
#  'or_later': 13.913825368307583,
#  'living_creature': 82.51963993453354,
#  'first_month': 25.952445658418213,
#  'have_transgressed': 23.003695592663565,
#  ...}

# %%
lower_bigram["jon lives in new york city".split()]
# Out:
# ['jon', 'lives', 'in', 'new_york', 'city']

# %%
lower_bigram = Phraser(Phrases(lower_sents, min_count=32, threshold=64))
lower_bigram.phrasegrams
# Out:
# {'miss_taylor': 156.44059469941823,
#  'mr_woodhouse': 82.04651843976633,
#  'mr_weston': 75.87438262077481,
#  'mrs_weston': 160.6848509325892,
#  'great_deal': 93.36368125424357,
#  'mr_knightley': 161.74131790625913,
#  'miss_woodhouse': 229.03802722366902,
#  'years_ago': 74.31594785893046,
#  'mr_elton': 121.3990121932397,
#  'dare_say': 89.94000515807346,
#  'frank_churchill': 1316.4456593286038,
#  'miss_bates': 276.3958829169252,
#  'drawing_room': 84.91494947493561,
#  'mrs_goddard': 143.57843432545658,
#  'miss_smith': 73.03442128232508,
#  'few_minutes': 204.16834974753786,
#  'john_knightley': 83.03755747111268,
#  'don_t': 250.30957446808512,
#  'good_natured': 88.69936184891343,
#  'few_moments': 107.77584531675087,
#  'thousand_pounds': 166.51834523092802,
#  'o_clock': 89.14789088153574,
#  'jane_fairfax': 654.556591758761,
#  'miss_fairfax': 196.19987447261062,
#  'ma_am': 157.25846601094193,
#  'mrs_elton': 93.08931456265867,
#  'forty_years': 90.60220877269607,
#  'cut_off': 129.60290535032792,
#  'ten_thousand': 84.00099962514057,
#  'sir_walter': 399.5145142857143,
#  'lady_russell': 613.6301581282135,
#  'mr_elliot': 126.18129960463163,
#  'mrs_clay': 93.08931456265867,
#  'captain_wentworth': 529.8756608388247,
#  'mrs_musgrove': 85.21252640735679,
#  'charles_hayter': 92.03437785214481,
#  'captain_benwick': 241.4903708631299,
#  'mrs_smith': 84.60327207490248,
#  'mrs_dashwood': 115.06873605661974,
#  'mrs_ferrars': 102.75628184416551,
#  'sir_john': 95.83994133176884,
#  'lady_middleton': 350.26733319243175,
#  'mrs_jennings': 279.0655756128398,
#  'colonel_brandon': 1313.0078125,
#  'miss_dashwood': 76.66830732292917,
#  'won_t': 189.96708776595744,
#  'm_sure': 69.15069432539002,
#  'six_hundred': 73.57615079223149,
#  'gathered_together': 103.28066074898891,
#  'thou_shalt': 66.88233182614454,
#  'burnt_offerings': 299.15702343127646,
#  'sweet_savour': 286.17879256965944,
#  'unleavened_bread': 237.70041787206688,
#  'burnt_offering': 297.524653753951,
#  'afar_off': 108.14220347465505,
#  'take_heed': 86.38454061712328,
#  'sent_messengers': 79.21555418015616,
#  'thus_saith': 144.0289127889979,
#  'without_blemish': 83.71359108159393,
#  'peace_offerings': 176.2577199456205,
#  'sin_offering': 129.96079665512747,
#  'meat_offering': 210.66724956379434,
#  'fine_flour': 86.07682458386682,
#  'high_places': 129.8123390846559,
#  'fig_tree': 121.73722334004025,
#  'fir_tree': 72.6789393074867,
#  'mercy_endureth': 269.07674062361025,
#  'chief_priests': 116.31947753846512,
#  'jesus_christ': 172.16816954974848,
#  'holy_ghost': 313.0305073859987,
#  'o_er': 108.14993564993566,
#  'couldn_t': 171.76138536935215,
#  'didn_t': 220.51081560283686,
#  'little_jackal': 69.81254128038833,
#  'wasn_t': 120.2225788701394,
#  'isn_t': 131.96593211752787,
#  'doesn_t': 106.2634985949418,
#  'wouldn_t': 120.2225788701394,
#  'father_brown': 91.68277248710235,
#  'buster_bear': 479.87410772225826,
#  'green_forest': 336.377336276674,
#  'little_joe': 133.28784038147822,
#  'joe_otter': 1271.6141235813368,
#  'farmer_brown': 386.0517959689224,
#  'mock_turtle': 2528.8777429467086,
#  'dr_bull': 680.7870294599019,
#  'guinea_hen': 905.8822695035461,
#  'sir_arthur': 131.41924812030075,
#  'miss_somers': 160.06190476190477,
#  'mr_gresham': 87.31390492359932,
#  'mrs_theresa': 170.20061244665203,
#  'de_grey': 603.2109624246722,
#  'dr_middleton': 162.73103819257665,
#  'moby_dick': 4115.877551020408,
#  'sperm_whale': 297.3672297627185,
#  'mast_heads': 77.73589269195189,
#  'wee_l': 450.39751861042186}

# %%
clean_sents = []
for s in lower_sents:
    clean_sents.append(lower_bigram[s])

# %%
clean_sents[0:9]
# Out:
# [['emma', 'by', 'jane', 'austen', '1816'],
#  ['volume', 'i'],
#  ['chapter', 'i'],
#  ['emma',
#   'woodhouse',
#   'handsome',
#   'clever',
#   'and',
#   'rich',
#   'with',
#   'a',
#   'comfortable',
#   'home',
#   'and',
#   'happy',
#   'disposition',
#   'seemed',
#   'to',
#   'unite',
#   'some',
#   'of',
#   'the',
#   'best',
#   'blessings',
#   'of',
#   'existence',
#   'and',
#   'had',
#   'lived',
#   'nearly',
#   'twenty',
#   'one',
#   'years',
#   'in',
#   'the',
#   'world',
#   'with',
#   'very',
#   'little',
#   'to',
#   'distress',
#   'or',
#   'vex',
#   'her'],
#  ['she',
#   'was',
#   'the',
#   'youngest',
#   'of',
#   'the',
#   'two',
#   'daughters',
#   'of',
#   'a',
#   'most',
#   'affectionate',
#   'indulgent',
#   'father',
#   'and',
#   'had',
#   'in',
#   'consequence',
#   'of',
#   'her',
#   'sister',
#   's',
#   'marriage',
#   'been',
#   'mistress',
#   'of',
#   'his',
#   'house',
#   'from',
#   'a',
#   'very',
#   'early',
#   'period'],
#  ['her',
#   'mother',
#   'had',
#   'died',
#   'too',
#   'long',
#   'ago',
#   'for',
#   'her',
#   'to',
#   'have',
#   'more',
#   'than',
#   'an',
#   'indistinct',
#   'remembrance',
#   'of',
#   'her',
#   'caresses',
#   'and',
#   'her',
#   'place',
#   'had',
#   'been',
#   'supplied',
#   'by',
#   'an',
#   'excellent',
#   'woman',
#   'as',
#   'governess',
#   'who',
#   'had',
#   'fallen',
#   'little',
#   'short',
#   'of',
#   'a',
#   'mother',
#   'in',
#   'affection'],
#  ['sixteen',
#   'years',
#   'had',
#   'miss_taylor',
#   'been',
#   'in',
#   'mr_woodhouse',
#   's',
#   'family',
#   'less',
#   'as',
#   'a',
#   'governess',
#   'than',
#   'a',
#   'friend',
#   'very',
#   'fond',
#   'of',
#   'both',
#   'daughters',
#   'but',
#   'particularly',
#   'of',
#   'emma'],
#  ['between',
#   '_them_',
#   'it',
#   'was',
#   'more',
#   'the',
#   'intimacy',
#   'of',
#   'sisters'],
#  ['even',
#   'before',
#   'miss_taylor',
#   'had',
#   'ceased',
#   'to',
#   'hold',
#   'the',
#   'nominal',
#   'office',
#   'of',
#   'governess',
#   'the',
#   'mildness',
#   'of',
#   'her',
#   'temper',
#   'had',
#   'hardly',
#   'allowed',
#   'her',
#   'to',
#   'impose',
#   'any',
#   'restraint',
#   'and',
#   'the',
#   'shadow',
#   'of',
#   'authority',
#   'being',
#   'now',
#   'long',
#   'passed',
#   'away',
#   'they',
#   'had',
#   'been',
#   'living',
#   'together',
#   'as',
#   'friend',
#   'and',
#   'friend',
#   'very',
#   'mutually',
#   'attached',
#   'and',
#   'emma',
#   'doing',
#   'just',
#   'what',
#   'she',
#   'liked',
#   'highly',
#   'esteeming',
#   'miss_taylor',
#   's',
#   'judgment',
#   'but',
#   'directed',
#   'chiefly',
#   'by',
#   'her',
#   'own']]

# %%
clean_sents[6]
# Out:
# ['sixteen',
#  'years',
#  'had',
#  'miss_taylor',
#  'been',
#  'in',
#  'mr_woodhouse',
#  's',
#  'family',
#  'less',
#  'as',
#  'a',
#  'governess',
#  'than',
#  'a',
#  'friend',
#  'very',
#  'fond',
#  'of',
#  'both',
#  'daughters',
#  'but',
#  'particularly',
#  'of',
#  'emma']

# %% [markdown]
# #### Run word2vec

# %%
# max_vocab_size can be used instead of min_count (which has increased here)
model = Word2Vec(sentences=clean_sents, vector_size=64,
                 sg=1, window=10, epochs=5,
                 min_count=10, workers=4)
model.save('clean_gutenberg_model.w2v')

# %% [markdown]
# #### Explore model

# %%
# skip re-training the model with the next line:
model = gensim.models.Word2Vec.load('clean_gutenberg_model.w2v')

# %%
len(model.wv.key_to_index) # would be 17k if we carried out no preprocessing but now it's 10k
# Out:
# 10329

# %%
model.wv['dog']
# Out:
# array([ 0.13172391, -0.16435581, -0.1151046 , -0.31551576,  0.26341647,
#        -0.3535435 ,  0.1470184 ,  0.7081606 , -0.31376132,  0.17258963,
#        -0.3887725 ,  0.00991731, -0.14843802, -0.30420437, -0.2751376 ,
#        -0.3224592 ,  0.11876482,  0.26303637, -0.4431448 ,  0.12895602,
#        -0.02267757,  0.18790579,  0.38507548, -0.4532743 ,  0.20111139,
#         0.26555452, -0.57902056,  0.47026885,  0.44466516, -0.1557655 ,
#         0.22771473, -0.09585681,  0.17821072,  0.14997394,  0.13540278,
#        -0.13461383,  0.5314365 ,  0.22642225, -0.00967272,  0.43841752,
#        -0.28447962,  0.17795715, -0.0559075 , -0.23835593,  0.20496044,
#        -0.02371392, -0.11897177, -0.00580008, -0.66651845,  0.06760759,
#        -0.19827831,  0.10301548,  0.16281566, -0.02465179,  0.36974835,
#         0.36373943,  0.07244937,  0.04929057, -0.00383553,  0.2853056 ,
#         0.2007627 , -0.3422567 , -0.18615088, -0.3604354 ], dtype=float32)

# %%
len(model.wv['dog'])
# Out:
# 64

# %%
model.wv.most_similar('father', topn=3)
# Out:
# [('mother', 0.8260319232940674),
#  ('brother', 0.7171385288238525),
#  ('curseth', 0.7046300172805786)]

# %%
model.wv.most_similar('eat', topn=3)
# Out:
# [('bread', 0.8581683039665222),
#  ('drink', 0.8250018954277039),
#  ('meat', 0.7629506587982178)]

# %%
model.wv.most_similar('day', topn=3)
# Out:
# [('morning', 0.8063955307006836),
#  ('night', 0.7382333874702454),
#  ('evening', 0.7246159911155701)]

# %%
model.wv.most_similar('father', topn=3)
# Out:
# [('mother', 0.8260319232940674),
#  ('brother', 0.7171385288238525),
#  ('curseth', 0.7046300172805786)]

# %%
model.wv.most_similar('ma_am', topn=3)
# Out:
# [('betty', 0.8623684048652649),
#  ('mamma', 0.8549090623855591),
#  ('nancy', 0.8489376306533813)]

# %%
model.wv.doesnt_match("mother father sister brother dog".split())
# Out:
# 'dog'

# %%
model.wv.similarity('father', 'dog')
# Out:
# 0.43486038

# %%
model.wv.most_similar(positive=['father', 'woman'], negative=['man'])
# Out:
# [('mother', 0.8164916634559631),
#  ('sister', 0.7841663360595703),
#  ('husband', 0.7688186168670654),
#  ('wife', 0.7606627345085144),
#  ('daughter', 0.7604349851608276),
#  ('tamar', 0.6940335035324097),
#  ('nurse', 0.6881982684135437),
#  ('daughters', 0.6783787608146667),
#  ('maid', 0.6781161427497864),
#  ('dearly', 0.6760234236717224)]

# %%
model.wv.most_similar(positive=['husband', 'woman'], negative=['man'])
# Out:
# [('wife', 0.7264155149459839),
#  ('sister', 0.7192351222038269),
#  ('maid', 0.7078677415847778),
#  ('daughter', 0.6992933750152588),
#  ('mother', 0.6609629392623901),
#  ('conceived', 0.6328186392784119),
#  ('child', 0.6326243877410889),
#  ('nurse', 0.6250259280204773),
#  ('adultery', 0.6190358996391296),
#  ('elder', 0.6158627271652222)]

# %% [markdown]
# #### Reduce word vector dimensionality with t-SNE

# %%
tsne = TSNE(n_components=2, n_iter=1000)

# %%
X_2d = tsne.fit_transform(model.wv[model.wv.key_to_index])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
coords_df = pd.DataFrame(X_2d, columns=['x','y'])
coords_df['token'] = list(model.wv.key_to_index.keys())

# %%
coords_df.head()
# Out:
#            x          y token
# 0 -19.991713  29.031069   the
# 1 -19.954842  28.936724   and
# 2 -20.001801  29.248829    of
# 3 -20.544214  28.239220    to
# 4 -22.246490  27.930584     a

# %%
coords_df.to_csv('clean_gutenberg_tsne.csv', index=False)

# %% [markdown]
# #### Visualise

# %%
coords_df = pd.read_csv('clean_gutenberg_tsne.csv')

# %%
output_notebook()

# %%
subset_df = coords_df.sample(n=5000)

# %%
p = figure(width=800, height=800)
_ = p.text(x=subset_df.x, y=subset_df.y, text=subset_df.token)

# %%
show(p)
# Out:
#   <div id="fb486db4-1cb4-4887-a647-982a6a2b02a9" data-root-id="p1013" style="display: contents;"></div>
